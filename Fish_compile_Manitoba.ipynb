# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as graph
import seaborn as sns

import cartopy.crs as ccrs

import statsmodels

import os
from tqdm import tqdm, trange

from convertbng.util import convert_bng, convert_lonlat
import utm

# %%
# code and species dictionary

code_df = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Alberta/To_look_at/Banff_NP_Freshwater_Lake_Fish_Index_2017_data_dictionary.csv')
# code_df = code_df.iloc[:-6]
code_df.rename(columns={'Data_Value_Valeur_de_la_donnée': 'code_name', 
                        'Value_Description_EN_Description_de_la_valeur': 'common_name'}, inplace=True)
code_df = code_df[['code_name', 'common_name']]
code_df['common_name'] = code_df['common_name'].str.lower().str.replace(' ', '_')
display(code_df.sample(5))

dict_code_name = code_df.set_index('code_name').to_dict()['common_name']
# Out:
#    code_name      common_name
# 47      WALL          walleye
# 26      EMSH   emerald_shiner
# 32      LKTR       lake_trout
# 12        OU       ouananiche
# 18      ARGR  arctic_grayling

# %%
new_codes = {'LNDC': 'longnose_dace', 'BNTR': 'brown_trout', 'RNTR1': 'rainbow_trout', 'CTTR1': 'cutthroat_trout', 
             'WHSC': 'white_sucker', 'BLTRCTTR(N&I)': 'bull_trout_x_cutthroat_trout', 'CTTR(hybrids)': 'cutthroat_trout', 
             'CTTRhybrids': 'cutthroat_trout', 'SUCK': 'white_sucker'}

dict_code_name.update(new_codes)

# %%
# Species dictionay

species_name_df = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/species_name_dictionary.csv')

dict_species_name = species_name_df.set_index('common_name').to_dict()['scientific_name']

# %%
new_names = {'nine-spine_stickleback': 'pungitius_pungitius'}

dict_species_name.update(new_names)
dict_species_name
# Out:
# {'striped_bass': 'morone_saxatilis',
#  'american_shad': 'alosa_sapidissima',
#  'white_sucker': 'catostomus_commersonii',
#  'channel_catfish': 'ictalurus_punctatus',
#  'mooneye': 'hiodon_tergisus',
#  'walleye': 'sander_vitreus',
#  'lake_sturgeon': 'acipenser_fulvescens',
#  'rainbow_smelt': 'osmerus_mordax',
#  'longnose_sucker': 'catostomus_catostomus',
#  'alewife': 'alosa_pseudoharengus',
#  'american_eel': 'anguilla_rostrata',
#  'white_perch': 'morone_americana',
#  'quillback': 'carpiodes_cyprinus',
#  'smallmouth_bass': 'micropterus_dolomieu',
#  'silver_redhorse': 'moxostoma_anisurum',
#  'logperch': 'percina_caprodes',
#  'tessellated_darter': 'etheostoma_olmstedi',
#  'brown_bullhead': 'ameiurus_nebulosus',
#  'longnose_gar': 'lepisosteus_osseus',
#  'freshwater_drum': 'aplodinotus_grunniens',
#  'fallfish': 'semotilus_corporalis',
#  'channel_darter': 'percina_copelandi',
#  'emerald_shiner': 'notropis_atherinoides',
#  'johnny_darter': 'etheostoma_nigrum',
#  'tadpole_madtom': 'noturus_gyrinus',
#  'trout-perch': 'percopsis_omiscomaycus',
#  'chestnut_lamprey': 'ichthyomyzon_castaneus',
#  'largemouth_bass': 'micropterus_salmoides',
#  'black_crappie': 'pomoxis_nigromaculatus',
#  'winter_flounder': 'pseudopleuronectes_americanus',
#  'three-spined_stickleback': 'gasterosteus_aculeatus',
#  'sand_shiner': 'notropis_stramineus',
#  'common_carp': 'cyprinus_carpio',
#  'bowfin': 'amia_calva',
#  'greater_redhorse': 'moxostoma_valenciennesi',
#  'atlantic_mackerel': 'scomber_scombrus',
#  'brook_trout': 'salvelinus_fontinalis',
#  'atlantic_snailfish': 'liparis_atlanticus',
#  'greenland_cod': 'gadus_ogac',
#  'muskellunge': 'esox_masquinongy',
#  'northern_pike': 'esox_lucius',
#  'cisco': 'coregonus_artedi',
#  'banded_killifish': 'fundulus_diaphanus',
#  'ocean_pout': 'zoarces_americanus',
#  'ninespine_stickleback': 'pungitius_pungitius',
#  'polar_cod': 'boreogadus_saida',
#  'tench': 'tinca_tinca',
#  'atlantic_sturgeon': 'acipenser_oxyrinchus',
#  'atlantic_herring': 'clupea_harengus',
#  'burbot': 'lota_lota',
#  'shorthead_redhorse': 'moxostoma_macrolepidotum',
#  'mottled_sculpin': 'cottus_bairdii',
#  'yellow_bullhead': 'ameiurus_natalis',
#  'american_gizzard_shad': 'dorosoma_cepedianum',
#  'american_sand_lance': 'ammodytes_americanus',
#  'mimic_shiner': 'notropis_volucellus',
#  'rock_bass': 'ambloplites_rupestris',
#  'silver_lamprey': 'ichthyomyzon_unicuspis',
#  'golden_shiner': 'notemigonus_crysoleucas',
#  'round_goby': 'neogobius_melanostomus',
#  'atlantic_tomcod': 'microgadus_tomcod',
#  'lake_whitefish': 'coregonus_clupeaformis',
#  'smooth_flounder': 'pleuronectes_putnami',
#  'shorthorn_sculpin': 'myoxocephalus_scorpius',
#  'slimy_sculpin': 'cottus_cognatus',
#  'white_bass': 'morone_chrysops',
#  'atlantic_salmon': 'salmo_salar',
#  'sauger': 'sander_canadensis',
#  'butterfish': 'peprilus_triacanthus',
#  'pumpkinseed': 'lepomis_gibbosus',
#  'spottail_shiner': 'notropis_hudsonius',
#  'northern_brook_lamprey': 'ichthyomyzon_fossor',
#  'brook_silverside': 'labidesthes_sicculus',
#  'sea_lamprey': 'petromyzon_marinus',
#  'rainbow_trout': 'oncorhynchus_mykiss',
#  'yellow_perch': 'perca_flavescens',
#  'bluntnose_minnow': 'pimephales_notatus',
#  'fourspine_stickleback': 'apeltes_quadracus',
#  'blackchin_shiner': 'notropis_heterodon',
#  'shiner_sp.': 'notropis_sp.',
#  'spotfin_shiner': 'cyprinella_spiloptera',
#  'sucker_sp.': 'catostomus_sp.',
#  'catostomid_sp.': 'catostomidae',
#  'stonecat': 'noturus_flavus',
#  'allis_shad': 'alosa_sp.',
#  'chinook_salmon': 'oncorhynchus_tshawytscha',
#  'copper_redhorse': 'moxostoma_hubbsi',
#  'cyprinid_sp.': 'cyprinidae_sp.',
#  'coho_salmon': 'oncorhynchus_kisutch',
#  'bass_sp.': 'micropterus_sp.',
#  'bluegill': 'lepomis_macrochirus',
#  'river_redhorse': 'moxostoma_carinatum',
#  'redhorse_sp.': 'moxostoma_sp.',
#  'cutlip_minnow': 'exoglossum_maxillingua',
#  'pikeperches_sp.': 'sander_sp.',
#  'petromyzontid_sp.': 'petromyzontidae_sp.',
#  'common_shiner': 'luxilus_cornutus',
#  'eastern_silvery_minnow': 'hybognathus_regius',
#  'rudd': 'scardinius_erythrophthalmus',
#  'smoothbelly_darters_sp.': 'etheostoma_sp.',
#  'redfin_pickerel': 'esox_americanus_americanus',
#  'fantail_darter': 'etheostoma_flabellare',
#  'brook_stickleback': 'culaea_inconstans',
#  'longnose_dace': 'rhinichthys_cataractae',
#  'iowa_darter': 'etheostoma_exile',
#  'bridle_shiner': 'notropis_bifrenatus',
#  'central_mudminnow': 'umbra_limi',
#  'creek_chub': 'semotilus_atromaculatus',
#  'eastern_sand_darter': 'ammocrypta_pellucida',
#  'fathead_minnow': 'pimephales_promelas',
#  'blacknose_shiner': 'notropis_heterolepis',
#  'rosyface_shiner': 'notropis_rubellus',
#  'brown_trout': 'salmo_trutta',
#  'capelin': 'mallotus_villosus',
#  'grubby_little_sculpin': 'myoxocephalus_aenaeus',
#  'blueback_herring': 'alosa_aestivalis',
#  'pearl_dace': 'margariscus_margarita',
#  'lake_trout': 'salvelinus_namaycush',
#  'goldfish': 'carassius_auratus',
#  'chain_pickerel': 'esox_niger',
#  'spoonhead_sculpin': 'cottus_ricei',
#  'snakeblenny': 'lumpenus_lampretaeformis',
#  'daubed_shanny': 'leptoclinus_maculatus',
#  'stout_eelblenny': 'anisarchus_medius',
#  'wrymouth': 'cryptacanthodes_maculatus',
#  'arctic_hookear_sculpin': 'artediellus_uncinatus',
#  'sea_raven': 'hemitripterus_americanus',
#  'atlantic_hookear_sculpin': 'artediellus_atlanticus',
#  'fish_doctor': 'gymnelus_viridis',
#  'atlantic_soft_pout': 'melanostigma_atlanticum',
#  'northern_wolf_eel': 'lycenchelys_paxillus',
#  'stout_sawpalate': 'serrivomer_beanii',
#  'slender_snipe_eel': 'nemichthys_scolopaceus',
#  'northern_cutthroat_eel': 'synaphobranchus_kaupii',
#  'snubnosed_spiny_eel': 'notacanthus_chemnitzii',
#  'longfin_hake': 'phycis_chesteri',
#  'pollock': 'pollachius_virens',
#  'atlantic_saury': 'scomberesox_saurus',
#  'longnose_greeneye': 'parasudis_truculenta',
#  'white_barracudina': 'arctozenus_risso',
#  'monkfish': 'lophius_americanus',
#  'triplewart_seadevil': 'cryptopsaras_couesii',
#  'witch_flounder': 'glyptocephalus_cynoglossus',
#  'american_plaice': 'hippoglossoides_platessoides',
#  'veiled_anglemouth': 'cyclothone_microdon',
#  'atlantic_argentine': 'argentina_silus',
#  "sloane's_viperfish": 'chauliodus_sloani',
#  'slope_hatchetfish': 'polyipnus_clarus',
#  'glowingfish': 'neoscopelus_macrolepidotus',
#  'boa_dragonfish': 'stomias_boa',
#  "kroyer's_lanternfish": 'notoscopelus_elongatus',
#  'glacier_lanternfish': 'benthosema_glaciale',
#  'mirror_lampfish': 'lampadena_speculigera',
#  'sea_tadpole': 'careproctus_reinhardti',
#  'lowfin_snailfish': 'paraliparis_calidus',
#  'alligatorfish': 'aspidophoroides_monopterygius',
#  'atlantic_poacher': 'leptagonus_decagonus',
#  'arctic_alligatorfish': 'ulcina_olrikii',
#  'yellowtail_flounder': 'limanda_ferruginea',
#  'longhorn_sculpin': 'myoxocephalus_octodecemspinosus',
#  'wolf_eelpout': 'lycenchelys_verrillii',
#  'golden_redfish': 'sebastes_norvegicus',
#  'redfish_sp.': 'sebastes',
#  'variegated_snailfish': 'liparis_gibbus',
#  'blacksnout_seasnail': 'paraliparis_copei',
#  'lumpfish': 'cyclopterus_lumpus',
#  'atlantic_cod': 'gadus_morhua',
#  'blue_whiting': 'micromesistius_poutassou',
#  'haddock': 'melanogrammus_aeglefinus',
#  'fourline_snakeblenny': 'eumesogrammus_praecisus',
#  'threebeard_rockling': 'gaidropsarus_ensis',
#  'silver_hake': 'merluccius_bilinearis',
#  'winter_skate': 'leucoraja_ocellata',
#  'barndoor_skate': 'dipturus_laevis',
#  'atlantic_hagfish': 'myxine_glutinosa',
#  'northern_wolffish': 'anarhichas_denticulatus',
#  'atlantic_wolffish_(striped)': 'anarhichas_lupus',
#  'spotted_wolffish': 'anarhichas_minor',
#  'checker_eelpout': 'lycodes_vahlii',
#  'newfoundland_eelpout': 'lycodes_lavalaei',
#  'arctic_eelpout': 'lycodes_reticulatus',
#  'greater_eelpout_(esmark)': 'lycodes_esmarkii',
#  'bigeye_sculpin': 'triglops_nybelini',
#  'moustache_sculpin': 'triglops_murrayi',
#  'ribbed_sculpin': 'triglops_pingelii',
#  'radiated_shanny': 'ulvaria_subbifurcata',
#  'slender_eelblenny': 'lumpenus_fabricii',
#  'twohorn_sculpin': 'icelus_bicornis',
#  'spatulate_sculpin': 'icelus_spatula',
#  'polar_sculpin': 'cottunculus_microps',
#  'fourhorn_sculpin': 'myoxocephalus_quadricornis',
#  'arctic_staghorn_sculpin': 'gymnocanthus_tricuspis',
#  'atlantic_spiny_lumpsucker': 'eumicrotremus_spinosus',
#  'atlantic_halibut': 'hippoglossus_hippoglossus',
#  'greenland_halibut': 'reinhardtius_hippoglossoides',
#  'silver_rockling': 'gaidropsarus_argentatus',
#  'fourbeard_rockling': 'enchelyopus_cimbrius',
#  'marlin-spike': 'nezumia_bairdii',
#  'arctic_shanny': 'stichaeus_punctatus',
#  'rock_gunnel': 'pholis_gunnellus',
#  'atlantic_eelpout': 'lycodes_terraenovae',
#  'pale_eelpout': 'lycodes_pallidus',
#  'sand_lance_sp.': 'ammodytes_sp.',
#  'black_dogfish': 'centroscyllium_fabricii',
#  'smooth_skate': 'malacoraja_senta',
#  'thorny_skate': 'amblyraja_radiata',
#  'shorttail_skate': 'amblyraja_jenseni',
#  'round_skate': 'rajella_fyllae',
#  'white_hake': 'urophycis_tenuis',
#  'spinytail_skate': 'bathyraja_spinicauda',
#  'spiny_dogfish': 'squalus_acanthias',
#  'northern_sand_lance': 'ammodytes_dubius',
#  'atlantic_silverside_': 'menidia_menidia',
#  'myoxocephalus_sp.': 'myoxocephalus_sp.',
#  'mummichog': 'fundulus_heteroclitus',
#  'basking_shark': 'cetorhinus_maximus',
#  'cunner_': 'tautogolabrus_adspersus',
#  'sunfish': 'mola_mola',
#  'northern_pipefish': 'syngnathus_fuscus',
#  'atlantic_bluefin_tuna': 'thunnus_thynnus',
#  'gelatinous_seasnail': 'liparis_fabricii',
#  'bartail_snailfish': 'liparis_tunicatus',
#  'deepwater_sculpin': 'myoxocephalus_thompsonii',
#  'lake_chub': 'couesius_plumbeus',
#  'finescale_dace': 'chrosomus_neogaeus',
#  'tullibee_(cisco)': 'coregonus_artedi',
#  'bull_trout': 'salvelinus_confluentus',
#  'grass_carp': 'ctenopharyngodon_idella',
#  'goldeye': 'hiodon_alosoides',
#  'flathead_chub': 'Platygobio gracilis',
#  'threespine_stickleback': 'gasterosteus_aculeatus',
#  'northern_redbelly_dace': 'chrosomus_eos',
#  'mountain_whitefish': 'prosopium_williamsoni',
#  'arctic_grayling': 'thymallus_arcticus',
#  'minnow_family': 'cyprinidae_spp',
#  'brassy_minnow': 'hybognathus_hankinsoni',
#  'arctic_grayling_(belly_popln)': 'thymallus_arcticus',
#  'river_shiner': 'notropis_blennius',
#  'sucker_family': 'catostomidae_spp',
#  'pygmy_whitefish': 'prosopium_coulterii',
#  'athabasca_rainbow_trout': 'oncorhynchus_mykiss',
#  'round_whitefish': 'prosopium_cylindraceum',
#  'largescale_sucker': 'catostomus_macrocheilus',
#  'northern_crayfish': 'orconectes_virilis',
#  'mountain_sucker': 'catostomus_platyrhynchus',
#  'redside_shiner': 'richardsonius_balteatus',
#  'cutthroat_trout': 'oncorhynchus_clarkii',
#  'bull_trout_x_brook_trout_hybrid': 'salvelinus_fontinalis_x_confluentus',
#  'prussian_carp': 'carassius_gibelio',
#  'tiger_trout': 'salmo_trutta_x_salvelinus_fontinalis',
#  'northern_redbelly_dace_x_finescale_dace': 'chrosomus_eos_×_chrosomus_neogaeus',
#  'sculpin_sp.': 'cottoidea_spp',
#  'northern_pikeminnow': 'ptychocheilus_oregonensis',
#  'yellowtone_cutthroat_trout': 'oncorhynchus_clarkii_bouvieri',
#  'cutthroat_trout_x_rainbow_trout': 'oncorhynchus_clarkii_x_oncorhynchus_mykiss',
#  'golden_trout': 'oncorhynchus_aguabonita',
#  'westslope_cutthroat_trout': 'oncorhynchus_clarkii',
#  'kokanee': 'oncorhynchus_nerka',
#  'tiger_salamander': 'ambystoma_tigrinum',
#  'dolly_varden': 'salvelinus_malma',
#  'giant_floater': 'pyganodon_grandis',
#  'trout_family': 'salmonidae_spp',
#  'arctic_char': 'salvelinus_alpinus',
#  'tullibee_(cisco)_x_lake_whitefish': 'coregonus_artedi_x_coregonus_clupeaformis',
#  'trout': 'salmonidae_spp',
#  'black_bullhead': 'ameiurus_melas',
#  'prickly_sculpin': 'cottus_asper',
#  'peamouth_chub': 'mylocheilus_caurinus',
#  'chinese_mystery_snail': 'cipangopaludina_chinensis',
#  'western_silvery_minnow': 'hybognathus_argyritis',
#  'rocky_mountain_sculpin': 'cottus_spp',
#  'cichlid': 'cichlidae',
#  'carp_sp.': 'cyprinidae',
#  'koi': 'cyprinus_rubrofuscus',
#  'shortjaw_cisco': 'coregonus_zenithicus',
#  'splake': 'salvelinus_fontinalis_×_salvelinus_namaycush',
#  'trout_perch': 'percopsis_omiscomaycus',
#  'ouaniche': 'salmo_salar',
#  'longsnose_dace': 'rhinichthys_cataractae',
#  'bull_trout_x_cutthroat_trout': 'salvelinus_confluentus_x_oncorhynchus_clarkii',
#  'landlocked_salmon': 'salmo_salar',
#  'fall_fish': 'semotilus_corporalis',
#  'tomcod': 'microgadus_tomcod',
#  'three_spine_stickleback': 'gasterosteus aculeatus',
#  'alewife_(gaspereau)': 'alosa_pseudoharengus',
#  'atlantic_whitefish': 'coregonus_huntsmani',
#  'atlantic_silverside': 'menidia_menidia',
#  'nine_spine_stickleback': 'pungitius_pungitius',
#  'four_spine_stickleback': 'apeltes_quadracus',
#  'black_nose_dace': 'rhinichthys_atratulus',
#  'three-spine_stickleback': 'gasterosteus aculeatus',
#  'nine-spine_stickleback': 'pungitius_pungitius',
#  'arctic_charr': 'salvelinus_alpinus',
#  'smelt': 'osmeridae',
#  'chum_salmon': 'oncorhynchus_keta',
#  'pink_salmon': 'oncorhynchus_gorbuscha',
#  'sockeye_salmon': 'oncorhynchus_nerka',
#  'dolly_varden_trout': 'salvelinus_malma',
#  'sheefish': 'stenodus_leucichthys',
#  'broad_whitefish': 'coregonus_nasus',
#  'steelhead_trout': 'oncorhynchus_mykiss',
#  'humpback_whitefish': 'coregonus_clupeaformis',
#  'least_cisco': 'coregonus_sardinella',
#  'shiner': 'notropis_hudsonius',
#  'arctic_cisco': 'coregonus_autumnalis'}

# %%
species_name_df = pd.DataFrame.from_dict({'common_name': list(dict_species_name.keys()), 
                                        'scientific_name' : list(dict_species_name.values())})
# species_name_df.to_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/species_name_dictionary.csv', index=False)

# %% [markdown]
# # Compiling stuff

# %% [markdown]
# ### Manitoba Drain Catch

# %%
df_location = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Manitoba/Used/mbagdrainssites.xlsx - Sites.csv')
df_location.rename(columns={'SiteName': 'waterbody_name', 'Latitude_DD': 'latitude', 'Longitude_DD': 'longitude', 
                            'Site Number': 'SiteNumber2'}, inplace=True)

df_location = df_location[['SiteNumber2', 'Date', 'waterbody_name', 'latitude', 'longitude']]
df_location['year'] = pd.DatetimeIndex(pd.to_datetime(df_location['Date'])).year
df_location.drop(columns=['Date'], inplace=True)

df_location['lat_long'] = df_location['latitude'].round(3).astype(str) + '_' + df_location['longitude'].round(3).astype(str)

df_location.head()
# Out:
#   SiteNumber2  waterbody_name  latitude  longitude  year         lat_long
# 0    D-02-001  Sturgeon Creek  49.87693  -97.27348  2002   49.877_-97.273
# 1    D-02-002  La Salle River  49.69432  -97.26246  2002   49.694_-97.262
# 2    D-02-003  Jackfish Creek  51.13015  -99.93745  2002    51.13_-99.937
# 3    D-02-004      Mink Creek  51.39807 -100.45823  2002  51.398_-100.458
# 4    D-02-005    Turtle River  50.90373  -99.50532  2002   50.904_-99.505

# %%
df_chemistry = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Manitoba/Used/mbagdrainschemistry.xlsx - Water_Chemistry.csv')
df_chemistry.rename(columns={'Latitude_DD': 'latitude', 'Longitude_DD': 'longitude'}, inplace=True)
df_chemistry.drop(columns=['SiteNumber', 'Date', 'latitude', 'longitude'], inplace=True)
df_chemistry.head()
# Out:
#   SiteNumber2  AirTemp_C WaterTemp_C  DissolvedOxygen_mg_L  DO_%Sat  \
# 0    D-02-001        4.6         1.6                 10.40    100.0
# 1    D-02-002        4.0         1.1                   NaN      NaN
# 2    D-02-003       -1.0         0.9                 11.50     99.0
# 3    D-02-004        NaN           5                 11.10     98.8
# 4    D-02-005        NaN         6.5                 10.69     98.6
#
#   Conductivity_µS_cm Turbidity_NTU pH_units
# 0                425           NaN      7.4
# 1                265           NaN     7.41
# 2                415           NaN     8.54
# 3                NaN           NaN      NaN
# 4                510           NaN     8.41

# %%
df_loc_chem = df_location.merge(df_chemistry, on=['SiteNumber2'])
print(len(df_loc_chem))
display(df_loc_chem.head())
# Out:
# 2371
#   SiteNumber2  waterbody_name  latitude  longitude  year         lat_long  \
# 0    D-02-001  Sturgeon Creek  49.87693  -97.27348  2002   49.877_-97.273
# 1    D-02-002  La Salle River  49.69432  -97.26246  2002   49.694_-97.262
# 2    D-02-003  Jackfish Creek  51.13015  -99.93745  2002    51.13_-99.937
# 3    D-02-004      Mink Creek  51.39807 -100.45823  2002  51.398_-100.458
# 4    D-02-005    Turtle River  50.90373  -99.50532  2002   50.904_-99.505
#
#    AirTemp_C WaterTemp_C  DissolvedOxygen_mg_L  DO_%Sat Conductivity_µS_cm  \
# 0        4.6         1.6                 10.40    100.0                425
# 1        4.0         1.1                   NaN      NaN                265
# 2       -1.0         0.9                 11.50     99.0                415
# 3        NaN           5                 11.10     98.8                NaN
# 4        NaN         6.5                 10.69     98.6                510
#
#   Turbidity_NTU pH_units
# 0           NaN      7.4
# 1           NaN     7.41
# 2           NaN     8.54
# 3           NaN      NaN
# 4           NaN     8.41

# %%
df_catch = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Manitoba/Used/mbagdrainscatch.xlsx - Catch.csv')
df_catch.rename(columns={'Site Number': 'SiteNumber2'}, inplace=True)
df_catch = df_catch[['SiteNumber2', 'Common Name']]
df_catch.dropna(inplace=True)

df_catch['Common Name'] = df_catch['Common Name'].str.lower().str.rstrip().str.replace(' ', '_')
df_catch['Common Name'].replace(dict_species_name, inplace=True)

df_catch = df_catch[~df_catch['Common Name'].isin(['no_catch', 'eggs', 'hybrid'])]
df_catch.drop_duplicates(inplace=True)

print(len(df_catch))
df_catch.head()
# Out:
# 3678
#   SiteNumber2              Common Name
# 2    D-02-002  semotilus_atromaculatus
# 3    D-02-002      pimephales_promelas
# 4    D-02-002        etheostoma_nigrum
# 5    D-02-002         percina_shumardi
# 6    D-02-002   rhinichthys_cataractae

# %%
df = df_catch.merge(df_loc_chem, how='left')
df.drop(columns=['SiteNumber2'], inplace=True)
print(len(df))
display(df.sample(5))
# Out:
# 3678
#                   Common Name                        waterbody_name  latitude  \
# 2818        culaea_inconstans    Unnamed tributary to St. Labre Bog  49.31111
# 1142      pimephales_promelas            East Branch Sturgeon Creek  50.06382
# 2417               umbra_limi  Unnamed tributary to Whitemouth Lake  49.24697
# 1141        culaea_inconstans            East Branch Sturgeon Creek  50.06382
# 451   semotilus_atromaculatus                        Bosshill Creek  49.84333
#
#       longitude  year        lat_long  AirTemp_C WaterTemp_C  \
# 2818  -95.99988  2005    49.311_-96.0       24.0        19.1
# 1142  -97.54338  2003  50.064_-97.543       24.5        20.1
# 2417  -95.78717  2004  49.247_-95.787       26.0        23.4
# 1141  -97.54338  2003  50.064_-97.543       24.5        20.1
# 451  -100.96983  2003  49.843_-100.97       25.5        18.5
#
#       DissolvedOxygen_mg_L  DO_%Sat Conductivity_µS_cm Turbidity_NTU pH_units
# 2818                  8.09    101.2                253             0     7.25
# 1142                  9.68    118.4                820             2      NaN
# 2417                  3.93     56.4                170             0     6.68
# 1141                  9.68    118.4                820             2      NaN
# 451                   8.83    104.7               1085            11     8.64

# %%
print(df['year'].min(), df['year'].max())

for col in df['Common Name'].unique():
    df[col] = np.where(df.isin([col]).any(1), 1, np.nan)
    df[col] = df[col].fillna(df.groupby(['year', 'lat_long'])[col].transform('mean'))
    
display(df)
# Out:
# 2002 2006
#                   Common Name              waterbody_name  latitude  \
# 0     semotilus_atromaculatus              La Salle River  49.69432
# 1         pimephales_promelas              La Salle River  49.69432
# 2           etheostoma_nigrum              La Salle River  49.69432
# 3            percina_shumardi              La Salle River  49.69432
# 4      rhinichthys_cataractae              La Salle River  49.69432
# ...                       ...                         ...       ...
# 3673      pimephales_promelas  Whitemud River Cross Ditch  50.24071
# 3674    aplodinotus_grunniens  Whitemud River Cross Ditch  50.24071
# 3675        etheostoma_nigrum  Whitemud River Cross Ditch  50.24071
# 3676      notropis_stramineus  Whitemud River Cross Ditch  50.24071
# 3677          noturus_gyrinus  Whitemud River Cross Ditch  50.24071
#
#       longitude  year        lat_long  AirTemp_C WaterTemp_C  \
# 0     -97.26246  2002  49.694_-97.262        4.0         1.1
# 1     -97.26246  2002  49.694_-97.262        4.0         1.1
# 2     -97.26246  2002  49.694_-97.262        4.0         1.1
# 3     -97.26246  2002  49.694_-97.262        4.0         1.1
# 4     -97.26246  2002  49.694_-97.262        4.0         1.1
# ...         ...   ...             ...        ...         ...
# 3673  -98.85887  2006  50.241_-98.859       30.0        26.2
# 3674  -98.85887  2006  50.241_-98.859       30.0        26.2
# 3675  -98.85887  2006  50.241_-98.859       30.0        26.2
# 3676  -98.85887  2006  50.241_-98.859       30.0        26.2
# 3677  -98.85887  2006  50.241_-98.859       30.0        26.2
#
#       DissolvedOxygen_mg_L  DO_%Sat  ... micropterus_dolomieu  \
# 0                      NaN      NaN  ...                  NaN
# 1                      NaN      NaN  ...                  NaN
# 2                      NaN      NaN  ...                  NaN
# 3                      NaN      NaN  ...                  NaN
# 4                      NaN      NaN  ...                  NaN
# ...                    ...      ...  ...                  ...
# 3673                 11.41    161.7  ...                  NaN
# 3674                 11.41    161.7  ...                  NaN
# 3675                 11.41    161.7  ...                  NaN
# 3676                 11.41    161.7  ...                  NaN
# 3677                 11.41    161.7  ...                  NaN
#
#      notemigonus_crysoleucas salmo_trutta  noturus_flavus  \
# 0                        NaN          NaN             NaN
# 1                        NaN          NaN             NaN
# 2                        NaN          NaN             NaN
# 3                        NaN          NaN             NaN
# 4                        NaN          NaN             NaN
# ...                      ...          ...             ...
# 3673                     NaN          NaN             NaN
# 3674                     NaN          NaN             NaN
# 3675                     NaN          NaN             NaN
# 3676                     NaN          NaN             NaN
# 3677                     NaN          NaN             NaN
#
#       cyprinella_spiloptera  aplodinotus_grunniens  moxostoma_macrolepidotum  \
# 0                       NaN                    NaN                       NaN
# 1                       NaN                    NaN                       NaN
# 2                       NaN                    NaN                       NaN
# 3                       NaN                    NaN                       NaN
# 4                       NaN                    NaN                       NaN
# ...                     ...                    ...                       ...
# 3673                    NaN                    1.0                       NaN
# 3674                    NaN                    1.0                       NaN
# 3675                    NaN                    1.0                       NaN
# 3676                    NaN                    1.0                       NaN
# 3677                    NaN                    1.0                       NaN
#
#       ictalurus_punctatus  hiodon_alosoides  oncorhynchus_mykiss
# 0                     NaN               NaN                  NaN
# 1                     NaN               NaN                  NaN
# 2                     NaN               NaN                  NaN
# 3                     NaN               NaN                  NaN
# 4                     NaN               NaN                  NaN
# ...                   ...               ...                  ...
# 3673                  NaN               NaN                  NaN
# 3674                  NaN               NaN                  NaN
# 3675                  NaN               NaN                  NaN
# 3676                  NaN               NaN                  NaN
# 3677                  NaN               NaN                  NaN
#
# [3678 rows x 68 columns]

# %%
print(len(df))
df.drop(columns=['Common Name'], inplace=True)
df.drop_duplicates(subset = df.columns[1:], inplace=True)
print(len(df))

display(df.sample(5))
# df.to_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Manitoba/Processed/manitoba_drain_catch_2002_2006_occurence.csv', 
#           index=False)
# Out:
# 3678
# 1021
#                             waterbody_name  latitude  longitude  year  \
# 2005             Sunny Valley School Drain  51.40645  -97.49728  2004
# 2809    Unnamed tributary to St. Labre Bog  49.31018  -96.07958  2005
# 3506                       Brelinski Creek  51.75018 -100.55737  2006
# 2797  Unnamed tributary to Icelandic River  51.00133  -97.36833  2005
# 2112                  Crooked Lake Channel  49.81292  -98.00272  2004
#
#             lat_long  AirTemp_C WaterTemp_C  DissolvedOxygen_mg_L  DO_%Sat  \
# 2005  51.406_-97.497       20.0        19.7                  7.31     90.7
# 2809    49.31_-96.08       25.0        17.8                  7.08     74.4
# 3506  51.75_-100.557       20.0        19.4                  8.42    113.6
# 2797  51.001_-97.368       22.0        20.5                 12.67      NaN
# 2112  49.813_-98.003        9.0         NaN                   NaN      NaN
#
#      Conductivity_µS_cm  ... micropterus_dolomieu notemigonus_crysoleucas  \
# 2005                NaN  ...                  NaN                     NaN
# 2809                489  ...                  NaN                     NaN
# 3506                302  ...                  NaN                     NaN
# 2797                NaN  ...                  NaN                     NaN
# 2112                NaN  ...                  NaN                     NaN
#
#       salmo_trutta  noturus_flavus  cyprinella_spiloptera  \
# 2005           NaN             NaN                    NaN
# 2809           NaN             NaN                    NaN
# 3506           NaN             NaN                    NaN
# 2797           NaN             NaN                    NaN
# 2112           NaN             NaN                    NaN
#
#       aplodinotus_grunniens  moxostoma_macrolepidotum  ictalurus_punctatus  \
# 2005                    NaN                       NaN                  NaN
# 2809                    NaN                       NaN                  NaN
# 3506                    NaN                       NaN                  NaN
# 2797                    NaN                       NaN                  NaN
# 2112                    NaN                       NaN                  NaN
#
#       hiodon_alosoides  oncorhynchus_mykiss
# 2005               NaN                  NaN
# 2809               NaN                  NaN
# 3506               NaN                  NaN
# 2797               NaN                  NaN
# 2112               NaN                  NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# # Devil's Lake

# %%
df = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Manitoba/Used/rrdevilslakephase3appendicesfishdata.csv')
df = df[['Species', 'Date of capture (dd/mm/yyyy)', 'Location (Manitoba)', 'N Latitude (DD)', 'LWBIN_Long']]

df.rename(columns={'Date of capture (dd/mm/yyyy)': 'year', 'Location (Manitoba)': 'waterbody_name', 
                   'N Latitude (DD)': 'latitude', 'LWBIN_Long': 'longitude'}, inplace=True)

df['year'] = pd.DatetimeIndex(pd.to_datetime(df['year'])).year

df['lat_long'] = df['latitude'].round(3).astype(str) + '_' + df['longitude'].round(3).astype(str)
df['Species'] = df['Species'].str.lower().str.rstrip().str.replace(' ', '_')
df['Species'].replace(dict_species_name, inplace=True)
df.drop_duplicates(inplace=True)

df.head()
# Out:
#                 Species  year        waterbody_name  latitude  longitude  \
# 0   pimephales_promelas  2007           Wavey Creek  50.26567 -96.975040
# 56  pimephales_promelas  2007  Emerson ( Red River)  49.00011 -97.230220
# 66  pimephales_promelas  2007        Baylor Pond- I  49.78013 -97.153483
# 72  pimephales_promelas  2008        Baylor Pond- I  49.78013 -97.153483
# 73  pimephales_promelas  2009        Baylor Pond- I  49.78013 -97.153483
#
#           lat_long
# 0   50.266_-96.975
# 56     49.0_-97.23
# 66   49.78_-97.153
# 72   49.78_-97.153
# 73   49.78_-97.153

# %%
print(df['year'].min(), df['year'].max())

for col in tqdm(df['Species'].unique()):
    df[col] = np.where(df.isin([col]).any(1), 1, np.nan)
    df[col] = df[col].fillna(df.groupby(['year', 'lat_long'])[col].transform('mean'))
    
display(df.sample(5))
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 190.59it/s]
# 2007 2011
#                    Species  year        waterbody_name  latitude  longitude  \
# 75     pimephales_promelas  2011        Baylor Pond- I  49.78013 -97.153483
# 206  notropis_atherinoides  2007               Selkirk  50.15042 -96.857570
# 0      pimephales_promelas  2007           Wavey Creek  50.26567 -96.975040
# 203  notropis_atherinoides  2007  Emerson ( Red River)  49.00011 -97.230220
# 168    pimephales_promelas  2007     Pembina/LaRiviera  49.23041 -98.675620
#
#            lat_long  pimephales_promelas  notropis_atherinoides  \
# 75    49.78_-97.153                  1.0                    NaN
# 206   50.15_-96.858                  NaN                    1.0
# 0    50.266_-96.975                  1.0                    NaN
# 203     49.0_-97.23                  1.0                    1.0
# 168   49.23_-98.676                  1.0                    NaN
#
#      luxilus_cornutus
# 75                NaN
# 206               NaN
# 0                 NaN
# 203               NaN
# 168               NaN

# %%
print(len(df))
df.drop(columns=['Species'], inplace=True)
df.drop_duplicates(subset = ['year', 'latitude', 'longitude','lat_long', 'pimephales_promelas', 'notropis_atherinoides',
                             'luxilus_cornutus'], inplace=True)
print(len(df))

display(df.head())
df.to_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Manitoba/Processed/devil_lake_2007_2011_occurence.csv', 
          index=False)
# Out:
# 14
# 10
#     year        waterbody_name  latitude  longitude        lat_long  \
# 0   2007           Wavey Creek  50.26567 -96.975040  50.266_-96.975
# 56  2007  Emerson ( Red River)  49.00011 -97.230220     49.0_-97.23
# 66  2007        Baylor Pond- I  49.78013 -97.153483   49.78_-97.153
# 72  2008        Baylor Pond- I  49.78013 -97.153483   49.78_-97.153
# 73  2009        Baylor Pond- I  49.78013 -97.153483   49.78_-97.153
#
#     pimephales_promelas  notropis_atherinoides  luxilus_cornutus
# 0                   1.0                    NaN               NaN
# 56                  1.0                    1.0               NaN
# 66                  1.0                    NaN               NaN
# 72                  1.0                    NaN               NaN
# 73                  1.0                    NaN               NaN

# %% [markdown]
# # Government Stocking

# %%
df = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Manitoba/Used/manitoba_gov_lake_stocking.csv')
df = df[['WATERBODY_NAME', 'YEAR_', 'SPECIES', 'WATERBODY_LAT', 'WATERBODY_LONG']]

df.columns = df.columns.str.lower().str.rstrip('_')
df.rename(columns={'waterbody_lat': 'latitude', 'waterbody_long': 'longitude'}, inplace=True)

df['lat_long'] = df['latitude'].round(3).astype(str) + '_' + df['longitude'].round(3).astype(str)
df['species'] = df['species'].str.lower().str.rstrip().str.replace(' ', '_')
df['species'].replace(dict_species_name, inplace=True)
df.drop_duplicates(inplace=True)

df.head()
# Out:
#         waterbody_name  year                               species   latitude  \
# 0  WOODPECKERS POND R4  2020                   oncorhynchus_mykiss  49.729755
# 1        LAC DU BONNET  2020                          salmo_trutta  50.366597
# 3        LAC DU BONNET  2020  salmo_trutta_x_salvelinus_fontinalis  50.366597
# 5        LAC DU BONNET  2020                   oncorhynchus_mykiss  50.366597
# 6            HUNT LAKE  2020                 salvelinus_fontinalis  49.742504
#
#    longitude        lat_long
# 0 -96.271489   49.73_-96.271
# 1 -95.916676  50.367_-95.917
# 3 -95.916676  50.367_-95.917
# 5 -95.916676  50.367_-95.917
# 6 -95.177395  49.743_-95.177

# %%
print(df['year'].min(), df['year'].max())

for col in tqdm(df['species'].unique()):
    df[col] = np.where(df.isin([col]).any(1), 1, np.nan)
    df[col] = df[col].fillna(df.groupby(['year', 'lat_long'])[col].transform('mean'))
    
display(df.sample(5))
# Out:
#  26%|██▌       | 7/27 [00:00<00:00, 67.06it/s]
# 1917 2020
# 100%|██████████| 27/27 [00:00<00:00, 46.30it/s]
#      waterbody_name  year                species   latitude   longitude  \
# 6610    HIDDEN LAKE  1989    oncorhynchus_mykiss  54.780047 -101.877813
# 8880    BIRCH RIVER  1973  salvelinus_fontinalis  49.648411  -95.726603
# 9852     PERCH LAKE  1964    oncorhynchus_mykiss  51.651389 -100.898611
# 286     SCOTTY LAKE  2019  salvelinus_fontinalis  54.733567 -101.670280
# 9790     PERCH LAKE  1965       esox_masquinongy  51.651389 -100.898611
#
#              lat_long  oncorhynchus_mykiss  salmo_trutta  \
# 6610   54.78_-101.878                  1.0           NaN
# 8880   49.648_-95.727                  NaN           NaN
# 9852  51.651_-100.899                  1.0           NaN
# 286    54.734_-101.67                  1.0           NaN
# 9790  51.651_-100.899                  NaN           NaN
#
#       salmo_trutta_x_salvelinus_fontinalis  salvelinus_fontinalis  ...  \
# 6610                                   NaN                    NaN  ...
# 8880                                   NaN                    1.0  ...
# 9852                                   NaN                    NaN  ...
# 286                                    1.0                    1.0  ...
# 9790                                   NaN                    NaN  ...
#
#       sander_canadensis  ambloplites_rupestris  morone_chrysops  \
# 6610                NaN                    NaN              NaN
# 8880                NaN                    NaN              NaN
# 9852                NaN                    NaN              NaN
# 286                 NaN                    NaN              NaN
# 9790                NaN                    NaN              NaN
#
#       thymallus_arcticus  oncorhynchus_nerka  siluriformes_spp  \
# 6610                 NaN                 NaN               NaN
# 8880                 NaN                 NaN               NaN
# 9852                 NaN                 NaN               NaN
# 286                  NaN                 NaN               NaN
# 9790                 NaN                 NaN               NaN
#
#       oncorhynchus_clarkii  micropterus_salmoides  pimephales_promelas  \
# 6610                   NaN                    NaN                  NaN
# 8880                   NaN                    NaN                  NaN
# 9852                   NaN                    NaN                  NaN
# 286                    NaN                    NaN                  NaN
# 9790                   NaN                    NaN                  1.0
#
#       chrosomus_neogaeus
# 6610                 NaN
# 8880                 NaN
# 9852                 NaN
# 286                  NaN
# 9790                 NaN
#
# [5 rows x 33 columns]

# %%
print(len(df))
df.drop(columns=['species'], inplace=True)
df.drop_duplicates(df.columns[1:], inplace=True)
print(len(df))

display(df.head())
df.to_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Manitoba/Processed/manitoba_gov_stocking_1917_2020_occurence.csv', 
          index=False)
# Out:
# 9851
# 8284
#         waterbody_name  year   latitude  longitude        lat_long  \
# 0  WOODPECKERS POND R4  2020  49.729755 -96.271489   49.73_-96.271
# 1        LAC DU BONNET  2020  50.366597 -95.916676  50.367_-95.917
# 6            HUNT LAKE  2020  49.742504 -95.177395  49.743_-95.177
# 8           LYONS LAKE  2020  49.733471 -95.177634  49.733_-95.178
# 9   MEADOWLARK POND R6  2020  49.731778 -96.272583  49.732_-96.273
#
#    oncorhynchus_mykiss  salmo_trutta  salmo_trutta_x_salvelinus_fontinalis  \
# 0                  1.0           1.0                                   NaN
# 1                  1.0           1.0                                   1.0
# 6                  NaN           1.0                                   NaN
# 8                  1.0           1.0                                   NaN
# 9                  NaN           NaN                                   NaN
#
#    salvelinus_fontinalis  sander_vitreus  ...  sander_canadensis  \
# 0                    1.0             NaN  ...                NaN
# 1                    NaN             NaN  ...                NaN
# 6                    1.0             NaN  ...                NaN
# 8                    NaN             NaN  ...                NaN
# 9                    1.0             NaN  ...                NaN
#
#    ambloplites_rupestris  morone_chrysops  thymallus_arcticus  \
# 0                    NaN              NaN                 NaN
# 1                    NaN              NaN                 NaN
# 6                    NaN              NaN                 NaN
# 8                    NaN              NaN                 NaN
# 9                    NaN              NaN                 NaN
#
#    oncorhynchus_nerka  siluriformes_spp  oncorhynchus_clarkii  \
# 0                 NaN               NaN                   NaN
# 1                 NaN               NaN                   NaN
# 6                 NaN               NaN                   NaN
# 8                 NaN               NaN                   NaN
# 9                 NaN               NaN                   NaN
#
#    micropterus_salmoides  pimephales_promelas  chrosomus_neogaeus
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 6                    NaN                  NaN                 NaN
# 8                    NaN                  NaN                 NaN
# 9                    NaN                  NaN                 NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# # Manitoba Anglers Stocking

# %%
df = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Manitoba/Used/manitoba_anglers_stocking.csv')
# df = df[['WATERBODY_NAME', 'YEAR_', 'SPECIES', 'WATERBODY_LAT', 'WATERBODY_LONG']]

df.columns = df.columns.str.lower().str.rstrip('_')
# df.rename(columns={'waterbody_lat': 'latitude', 'waterbody_long': 'longitude'}, inplace=True)

# df['lat_long'] = df['latitude'].round(3).astype(str) + '_' + df['longitude'].round(3).astype(str)
# df['species'] = df['species'].str.lower().str.rstrip().str.replace(' ', '_')
# df['species'].replace(dict_species_name, inplace=True)
# df.drop_duplicates(inplace=True)

df.head()
# Out:
#    objectid  waterbody_id       waterbody_name   fishing_division  year  \
# 0         1         39252  WOODPECKERS POND R4  Southern Division  2020
# 1         2         38891        LAC DU BONNET  Southern Division  2020
# 2         3         38891        LAC DU BONNET  Southern Division  2020
# 3         4         38891        LAC DU BONNET  Southern Division  2020
# 4         5         38891        LAC DU BONNET  Southern Division  2020
#
#          date        species            size  quantity     lat_dd    long_dd  \
# 0  2020-04-29  RAINBOW TROUT          18+ cm    1000.0  49.729755 -96.271489
# 1  2020-05-01    BROWN TROUT  Adult (>30 cm)      27.0  50.366597 -95.916676
# 2  2020-05-01    BROWN TROUT  Adult (>30 cm)      26.0  50.366597 -95.916676
# 3  2020-05-01    TIGER TROUT          18+ cm     500.0  50.366597 -95.916676
# 4  2020-05-01    BROWN TROUT          18+ cm    1000.0  50.366597 -95.916676
#
#    waterbody_lat  waterbody_long
# 0      49.729755      -96.271489
# 1      50.366597      -95.916676
# 2      50.366597      -95.916676
# 3      50.366597      -95.916676
# 4      50.366597      -95.916676

# %%
print(df['year'].min(), df['year'].max())

for col in df.columns[6:]:
    df[col] = np.where(df[col].notnull(), 1, df[col])
    df[col] = df[col].fillna(df.groupby(['year', 'lat_long'])[col].transform('mean'))

display(df.sample(5))
# Out:
# 2016 2016
#    waterbody_name site_description  year   latitude   longitude  \
# 10       WATERTON        Blakiston  2016  49.096255 -113.905775
# 33       WATERTON        Dungarven  2016  49.186081 -113.943429
# 31       WATERTON             Rowe  2016  49.056519 -114.049382
# 17       WATERTON      Blue Grouse  2016  49.120595 -114.141875
# 15       WATERTON          Crooked  2016  49.063478 -113.751008
#
#            lat_long  oncorhynchus_clarkii  salvelinus_fontinalis  \
# 10  49.096_-113.906                   NaN                    1.0
# 33  49.186_-113.943                   1.0                    1.0
# 31  49.057_-114.049                   NaN                    NaN
# 17  49.121_-114.142                   NaN                    NaN
# 15  49.063_-113.751                   NaN                    1.0
#
#     salvelinus_confluentus  oncorhynchus_mykiss  rhinichthys_cataractae  \
# 10                     1.0                  NaN                     NaN
# 33                     NaN                  NaN                     NaN
# 31                     NaN                  NaN                     NaN
# 17                     NaN                  NaN                     NaN
# 15                     NaN                  NaN                     NaN
#
#     catostomus_catostomus  catostomus_commersonii  percopsis_omiscomaycus  \
# 10                    NaN                     NaN                     NaN
# 33                    NaN                     NaN                     NaN
# 31                    NaN                     NaN                     NaN
# 17                    NaN                     NaN                     NaN
# 15                    NaN                     NaN                     NaN
#
#     lota_lota  salmo_trutta  oncorhynchus_clarkii_x_oncorhynchus_mykiss
# 10        NaN           NaN                                         NaN
# 33        NaN           NaN                                         1.0
# 31        NaN           NaN                                         NaN
# 17        NaN           NaN                                         NaN
# 15        NaN           NaN                                         NaN

# %%
print(len(df))
df.drop_duplicates(subset = df.columns[2:], inplace=True)
print(len(df))

display(df.sample(5))
df.to_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Saskatchewan/Processed/waterton_2016_occurence.csv', 
          index=False)
# Out:
# 43
# 27
#    waterbody_name site_description  year   latitude   longitude  \
# 13       WATERTON         Bauerman  2016  49.151866 -114.085320
# 3        WATERTON        Blakiston  2016  49.125808 -114.027050
# 40       WATERTON            Lone   2016  49.112359 -114.138086
# 8        WATERTON        Blakiston  2016  49.112009 -114.078900
# 7        WATERTON      Blue Grouse  2016  49.118292 -114.133194
#
#            lat_long  oncorhynchus_clarkii  salvelinus_fontinalis  \
# 13  49.152_-114.085                   NaN                    NaN
# 3   49.126_-114.027                   NaN                    NaN
# 40  49.112_-114.138                   NaN                    NaN
# 8   49.112_-114.079                   NaN                    NaN
# 7   49.118_-114.133                   NaN                    NaN
#
#     salvelinus_confluentus  oncorhynchus_mykiss  rhinichthys_cataractae  \
# 13                     NaN                  NaN                     NaN
# 3                      1.0                  NaN                     NaN
# 40                     NaN                  NaN                     NaN
# 8                      NaN                  NaN                     NaN
# 7                      NaN                  NaN                     NaN
#
#     catostomus_catostomus  catostomus_commersonii  percopsis_omiscomaycus  \
# 13                    NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 40                    NaN                     NaN                     NaN
# 8                     NaN                     NaN                     NaN
# 7                     NaN                     NaN                     NaN
#
#     lota_lota  salmo_trutta  oncorhynchus_clarkii_x_oncorhynchus_mykiss
# 13        NaN           NaN                                         NaN
# 3         NaN           NaN                                         NaN
# 40        NaN           NaN                                         NaN
# 8         NaN           NaN                                         NaN
# 7         NaN           NaN                                         NaN
