# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as graph
import seaborn as sns
import cartopy
import cartopy.crs as ccrs

from tqdm import tqdm
import swifter

from osgeo import ogr, osr, gdal
# from joblib import Parallel, delayed

tqdm.pandas()
import xarray as xr
from global_land_mask import globe
import geopandas as gpd
import geoplot

from datetime import date
today_date = date.today().strftime("%b_%d").lower()
import os

from convertbng.util import convert_bng, convert_lonlat
import utm

import shapefile as shp
from shapely.geometry import Point, Polygon, MultiPolygon
import imageio
import matplotlib as mpl

# %% [markdown]
# # Nick Watersheds

# %%
canada_lakes = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/hydrolakes_ahi_bsm_sapna_lake_caracteristics_aug_26.csv')
print(len(canada_lakes))

canada_lakes.drop_duplicates(inplace = True)

print(len(canada_lakes))
display(canada_lakes.head())
# Out:
# 24209
# 24209
#    Hylak_id   wby_name Country Continent  lake_area_km2  mean_depth_m  \
# 0       NaN  Bowlby P.     NaN       NaN          0.001           1.5
# 1       NaN      B, L.     NaN       NaN          0.001           NaN
# 2       NaN    H-A, L.     NaN       NaN          0.001           NaN
# 3       NaN    Eby Ph.     NaN       NaN          0.002           1.2
# 4       NaN  Vances L.     NaN       NaN          0.002           1.6
#
#    lake_elevation_(m)  longitude   latitude  dataset  surface_area_ha  \
# 0               201.0 -80.261111  42.793056  ahi_bsm              NaN
# 1               326.0 -80.200000  43.450000  ahi_bsm              NaN
# 2               332.0 -80.166667  43.500000  ahi_bsm              NaN
# 3               320.0 -80.163333  48.032500  ahi_bsm              NaN
# 4               265.0 -81.375000  44.233889  ahi_bsm              NaN
#
#    max_depth_m made_up_code
# 0          NaN          NaN
# 1          NaN          NaN
# ...

# %%
# ildf
gpd_canada_lakes = gpd.GeoDataFrame(canada_lakes, 
                                    geometry=gpd.points_from_xy(canada_lakes['longitude'], canada_lakes['latitude']))
gpd_canada_lakes.head()
# Out:
#    Hylak_id   wby_name Country Continent  lake_area_km2  mean_depth_m  \
# 0       NaN  Bowlby P.     NaN       NaN          0.001           1.5
# 1       NaN      B, L.     NaN       NaN          0.001           NaN
# 2       NaN    H-A, L.     NaN       NaN          0.001           NaN
# 3       NaN    Eby Ph.     NaN       NaN          0.002           1.2
# 4       NaN  Vances L.     NaN       NaN          0.002           1.6
#
#    lake_elevation_(m)  longitude   latitude  dataset  surface_area_ha  \
# 0               201.0 -80.261111  42.793056  ahi_bsm              NaN
# 1               326.0 -80.200000  43.450000  ahi_bsm              NaN
# 2               332.0 -80.166667  43.500000  ahi_bsm              NaN
# 3               320.0 -80.163333  48.032500  ahi_bsm              NaN
# 4               265.0 -81.375000  44.233889  ahi_bsm              NaN
#
#    max_depth_m made_up_code                    geometry
# 0          NaN          NaN  POINT (-80.26111 42.79306)
# ...

# %%
nick_shapefile = gpd.read_file('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Nick_Mandrak/Canada_shapefiles/Canada_watersheds_hydrolakes_our_lake_counts_pop_density.shp')
print(len(nick_shapefile))
nick_shapefile.head()
# Out:
# 991
#   WSCSSDA    TWS_Area_m  out_lakes_  hydro_lake  mean_pop_d  \
# 0    08JD  6.266462e+09        27.0       116.0    0.306156
# 1    05AK  5.335010e+09         2.0        31.0    4.017055
# 2    06CE  4.591652e+09         5.0       872.0    0.359558
# 3    07HE  6.463431e+09         3.0       121.0    0.160877
# 4    06CD  1.911540e+10        60.0      3054.0    0.280647
#
#                                             geometry
# 0  POLYGON ((-125.41910 55.11623, -125.41885 55.1...
# 1  POLYGON ((-109.89815 50.92035, -109.89509 50.9...
# 2  POLYGON ((-105.14596 56.98348, -105.14677 56.9...
# 3  POLYGON ((-116.42664 57.94598, -116.42025 57.9...
# 4  POLYGON ((-104.27707 56.09364, -104.27596 56.0...

# %% [markdown]
# # Calculate # lakes per hydroshed area and population density

# %% [markdown]
# ### Lakes

# %%
list_of_points = gpd.points_from_xy(canada_lakes.longitude, canada_lakes.latitude)

df_points = gpd.GeoSeries(list_of_points)
print(len(df_points))

# %%
# %%time
for i, row in tqdm(nick_shapefile.iterrows()):
    poly = row.geometry
    if isinstance(poly,MultiPolygon):
        count = 0
        for p in list(poly):
            count = count + df_points.intersects(p).sum()
    else:
        count = df_points.intersects(poly).sum()
#     nick_shapefile.loc[i,'our_lakes_count'] = count

# %% [markdown]
# ### Population Density

# %%
def create_square(lon,lat):
    result= Polygon([(lon-0.5,lat-0.5),(lon-0.5,lat+0.5),(lon+0.5,lat+0.5),(lon+0.5,lat-0.5),(lon-0.5,lat-0.5)])
    return result

# %%
ds = gdal.Open('/mnt/c/Users/imrit/Downloads/Population_density/gpw_v4_population_density_adjusted_to_2015_unwpp_country_totals_rev11_2020_1_deg.tif')
data = ds.ReadAsArray()
data.shape

# %%
lat = np.linspace(89.5,-89.5,180)
lon = np.linspace(-179.5,179.5, 360)
longrid,latgrid = np.meshgrid(lon,lat)

graph.imshow(data,norm=mpl.colors.LogNorm(vmin=0.1,vmax=100))
graph.colorbar()
graph.show()
graph.imshow(longrid)
graph.title('Longitude')
graph.colorbar()
graph.show()
graph.title('Latitude')
graph.imshow(latgrid)
graph.colorbar()
graph.show()

# %%
df_pop_den = pd.DataFrame({'lon': longrid.flatten(), 'lat': latgrid.flatten(),'popdens': data.flatten()})
df_pop_den = df_pop_den.loc[(df_pop_den['lon'] < -29) & (df_pop_den['lat'] > 30)]

display(df_pop_den.head())
print(df_pop_den.shape)

# %%
gdf = gpd.GeoDataFrame(df_pop_den,geometry = [create_square(lon,lat) for lon,lat in zip(df_pop_den.lon,df_pop_den.lat)])
gdf

# %%
# %%time
nrows = len(nick_shapefile)

for i, row in tqdm(nick_shapefile.iterrows()):
    poly = row.geometry
    if isinstance(poly,MultiPolygon):
        density_list = []
        for p in list(poly):
            ind = gdf['geometry'].intersects(p)
            density_list.extend(gdf.loc[ind,'popdens'].tolist())
        density = np.mean(density_list)
    else:
        ind = gdf['geometry'].intersects(poly)
        density = gdf.loc[ind,'popdens'].mean()
#     nick_shapefile.loc[i,'mean_pop_density'] = density

# %%
# nick_shapefile.drop(columns = ['binned_our_counts', 'binned_hydro_counts'], inplace = True)
# nick_shapefile.to_file('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Nick_Mandrak/Canada_shapefiles/Canada_watersheds_hydrolakes_our_lake_counts_pop_density.shp', 
#                        index = False)

# %% [markdown]
# # Calculate Bins

# %%
lakes_counts = pd.Series(nick_shapefile['out_lakes_'].values)
lakes_counts.replace(0, 0.1, inplace=True)
labels = ['0-1', '1-5', '5-10', '10-30', '30-50', '50-100', '>100']

cut_lakes_counts = pd.cut(lakes_counts, bins=[0, 1, 5, 10, 30, 50, 100, 900], labels=labels)
nick_shapefile['binned_our_counts'] = cut_lakes_counts

nick_shapefile.head(10)
# Out:
#   WSCSSDA    TWS_Area_m  out_lakes_  hydro_lake  mean_pop_d  \
# 0    08JD  6.266462e+09        27.0       116.0    0.306156
# 1    05AK  5.335010e+09         2.0        31.0    4.017055
# 2    06CE  4.591652e+09         5.0       872.0    0.359558
# 3    07HE  6.463431e+09         3.0       121.0    0.160877
# 4    06CD  1.911540e+10        60.0      3054.0    0.280647
# 5    08JC  8.817841e+09        71.0       248.0    2.473939
# 6    07HD  1.534211e+09         0.1        19.0    0.149339
# 7    05AH  6.343748e+09        10.0        55.0    2.516894
# 8    07HF  3.472724e+09         3.0        34.0    0.494176
# 9    05AG  3.325150e+09         6.0        17.0    6.288850
#
#                                             geometry binned_our_counts
# 0  POLYGON ((-125.41910 55.11623, -125.41885 55.1...             10-30
# 1  POLYGON ((-109.89815 50.92035, -109.89509 50.9...               1-5
# 2  POLYGON ((-105.14596 56.98348, -105.14677 56.9...               1-5
# ...

# %%
hydro_counts = pd.Series(nick_shapefile['hydro_lake'].values)
hydro_counts.replace(0, 0.1, inplace=True)
labels = ['0-1', '1-100', '100-500', '500-1000', '1000-5000', '5000-10000', '>10000']

cut_hydro_counts = pd.cut(hydro_counts, bins=[0, 1, 100, 500, 1000, 5000, 10000, 2000000], labels=labels)
nick_shapefile['binned_hydro_counts'] = cut_hydro_counts

nick_shapefile.head(10)
# Out:
#   WSCSSDA    TWS_Area_m  out_lakes_  hydro_lake  mean_pop_d  \
# 0    08JD  6.266462e+09        27.0       116.0    0.306156
# 1    05AK  5.335010e+09         2.0        31.0    4.017055
# 2    06CE  4.591652e+09         5.0       872.0    0.359558
# 3    07HE  6.463431e+09         3.0       121.0    0.160877
# 4    06CD  1.911540e+10        60.0      3054.0    0.280647
# 5    08JC  8.817841e+09        71.0       248.0    2.473939
# 6    07HD  1.534211e+09         0.1        19.0    0.149339
# 7    05AH  6.343748e+09        10.0        55.0    2.516894
# 8    07HF  3.472724e+09         3.0        34.0    0.494176
# 9    05AG  3.325150e+09         6.0        17.0    6.288850
#
#                                             geometry binned_our_counts  \
# 0  POLYGON ((-125.41910 55.11623, -125.41885 55.1...             10-30
# 1  POLYGON ((-109.89815 50.92035, -109.89509 50.9...               1-5
# 2  POLYGON ((-105.14596 56.98348, -105.14677 56.9...               1-5
# ...

# %%
popden_counts = pd.Series(nick_shapefile['mean_pop_d'].values)
popden_counts.replace(0, 0.1, inplace=True)
labels = ['0-0.05', '0.05-0.25', '0.25-1.5', '1.5-7.5', '>7.5']
pop_den_quantiles = ['0-0.04', '0.04-0.24', '0.24-1.5', '1.5-7.5', '>7.5']

cut_popden_counts = pd.cut(popden_counts, bins=[0, 0.05, 0.25, 1.5, 7.5, 700], labels=labels)
nick_shapefile['binned_popden_counts'] = cut_popden_counts

nick_shapefile.head(10)
# Out:
#   WSCSSDA    TWS_Area_m  out_lakes_  hydro_lake  mean_pop_d  \
# 0    08JD  6.266462e+09        27.0       116.0    0.306156
# 1    05AK  5.335010e+09         2.0        31.0    4.017055
# 2    06CE  4.591652e+09         5.0       872.0    0.359558
# 3    07HE  6.463431e+09         3.0       121.0    0.160877
# 4    06CD  1.911540e+10        60.0      3054.0    0.280647
# 5    08JC  8.817841e+09        71.0       248.0    2.473939
# 6    07HD  1.534211e+09         0.1        19.0    0.149339
# 7    05AH  6.343748e+09        10.0        55.0    2.516894
# 8    07HF  3.472724e+09         3.0        34.0    0.494176
# 9    05AG  3.325150e+09         6.0        17.0    6.288850
#
#                                             geometry binned_our_counts  \
# 0  POLYGON ((-125.41910 55.11623, -125.41885 55.1...             10-30
# 1  POLYGON ((-109.89815 50.92035, -109.89509 50.9...               1-5
# 2  POLYGON ((-105.14596 56.98348, -105.14677 56.9...               1-5
# ...

# %% [markdown]
# # Graphs

# %%
axis_label_size = 18
axis_tick_size = 14
figsize = (12, 9)

# %%
fig, ax = graph.subplots(figsize = figsize)

nick_shapefile.plot(column = 'binned_our_counts', legend = True, cmap = 'OrRd', zorder = 2, ax = ax)
sampled_gpd_canada_lakes.plot(ax = ax, zorder=1, markersize=0.000001, rasterized = True)
graph.xlabel('Longitude', fontsize = axis_label_size, labelpad=10)
graph.ylabel('Latitude', fontsize = axis_label_size, labelpad=10)
graph.xticks(fontsize = axis_tick_size)
graph.yticks(fontsize = axis_tick_size)
fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/watershed_canadian_sampled_lakes_density.pdf',
            bbox_inches='tight')
graph.show()

# %%
fig, ax = graph.subplots(figsize = figsize)

nick_shapefile.boundary.plot(zorder=2, edgecolor='black', linewidth = 0.05, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=1, markersize=2)
graph.xlabel('Longitude', fontsize = axis_label_size, labelpad=10)
graph.ylabel('Latitude', fontsize = axis_label_size, labelpad=10)
graph.xticks(fontsize = axis_tick_size)
graph.yticks(fontsize = axis_tick_size)
fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/sampled_canadian_lakes.pdf', 
            bbox_inches='tight')
graph.show()

# %%
fig, ax = graph.subplots(figsize = figsize)

nick_shapefile.plot(column='binned_hydro_counts', legend=True, cmap='OrRd', zorder=2, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=1, markersize=0.0001, rasterized = True)
graph.xlabel('Longitude', fontsize = axis_label_size, labelpad=10)
graph.ylabel('Latitude', fontsize = axis_label_size, labelpad=10)
graph.xticks(fontsize = axis_tick_size)
graph.yticks(fontsize = axis_tick_size)
fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/watershed_actual_canadian_lakes_location.pdf', 
            bbox_inches='tight')
graph.show()

# %%
fig, ax = graph.subplots(figsize = figsize)

nick_shapefile.plot(column='binned_popden_counts', legend=True, cmap='RdPu', zorder=2, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=1, markersize=0.0001, rasterized = True)
graph.xlabel('Longitude', fontsize = axis_label_size, labelpad=10)
graph.ylabel('Latitude', fontsize = axis_label_size, labelpad=10)
graph.xticks(fontsize = axis_tick_size)
graph.yticks(fontsize = axis_tick_size)
fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/watershed_human_population_density_red_purple_hue.pdf', 
            bbox_inches='tight')
graph.show()

# %%
for cmap in ['Purples', 'Blues', 'Greens', 'Oranges', 'Reds', 'PuRd', 'BuPu', 'RdPu', 'OrRd', 'YlOrBr', 
             'YlOrRd', 'GnBu', 'PuBu']:
    print(f'COLOR PALETTE IS: {cmap}')
    fig, ax = graph.subplots(figsize = figsize)

    nick_shapefile.plot(column='binned_popden_counts', legend=True, cmap=cmap, zorder=2, ax=ax, figsize = figsize)
    gpd_canada_lakes.plot(ax = ax, zorder=1, markersize=0.0001)
    graph.xlabel('Longitude', fontsize = axis_label_size, labelpad=10)
    graph.ylabel('Latitude', fontsize = axis_label_size, labelpad=10)
    graph.xticks(fontsize = axis_tick_size)
    graph.yticks(fontsize = axis_tick_size)
    graph.show()
# Out:
# COLOR PALETTE IS: Purples
# COLOR PALETTE IS: Blues
# COLOR PALETTE IS: Greens
# COLOR PALETTE IS: Oranges
# COLOR PALETTE IS: Reds
# COLOR PALETTE IS: PuRd
# COLOR PALETTE IS: BuPu
# COLOR PALETTE IS: RdPu
# COLOR PALETTE IS: OrRd
# COLOR PALETTE IS: YlOrBr
# COLOR PALETTE IS: YlOrRd
# COLOR PALETTE IS: GnBu
# COLOR PALETTE IS: PuBu
