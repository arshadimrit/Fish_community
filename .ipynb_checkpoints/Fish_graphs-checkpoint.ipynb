# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as graph
import seaborn as sns
import cartopy
import cartopy.crs as ccrs

from tqdm import tqdm
import swifter

# from osgeo import ogr, osr
# from joblib import Parallel, delayed

tqdm.pandas()
import xarray as xr
from global_land_mask import globe
import geopandas as gpd
import geoplot

from datetime import date
today_date = date.today().strftime("%b_%d").lower()
import os

from convertbng.util import convert_bng, convert_lonlat
import utm

import shapefile as shp
from shapely.geometry import Point, Polygon, MultiPolygon
import imageio

# %%
graph.figure(figsize=(16,9))
ax = graph.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)

# sns.scatterplot(df['longitude'], df['latitude'], transform=ccrs.PlateCarree(), hue=df['Year'])

graph.show()

# %%
df = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Master_compilation/locations_jan_30.csv')
df.head()
# Out:
#      year        lat_long  latitude  longitude
# 0  2006.0   46.496_-63.39  46.49648  -63.38951
# 1  2006.0   46.498_-63.39  46.49780  -63.39002
# 2  2006.0  46.498_-63.388  46.49759  -63.38835
# 3  2006.0  46.494_-63.384  46.49401  -63.38425
# 4  2006.0  46.492_-63.384  46.49215  -63.38435

# %%
graph.figure(figsize=(16, 9))
ax = graph.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)

sns.scatterplot(df['longitude'], df['latitude'], transform=ccrs.PlateCarree(), 
                hue=df['year'], palette='viridis', s=3)
# graph.legend()

ax.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Master_compilation/fish_data_location_year.png', dpi=400)
graph.show()
# Out:
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
# /home/arshad/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
graph.figure(figsize=(16,9))
ax = graph.axes(projection=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines(draw_labels=True)

sns.scatterplot(df['longitude'], df['latitude'], transform=ccrs.PlateCarree(), hue=df['total_species'], s=0.5)

graph.show()
# Out:
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
# /home/arshad/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Make gifs

# %%
before_1900 = np.arange(int(df['year'].min()), 1900, 7)
after_1900 = np.arange(1900, int(df['year'].max() + 1))
years = np.concatenate((before_1900, after_1900))
years
# Out:
# array([1655, 1662, 1669, 1676, 1683, 1690, 1697, 1704, 1711, 1718, 1725,
#        1732, 1739, 1746, 1753, 1760, 1767, 1774, 1781, 1788, 1795, 1802,
#        1809, 1816, 1823, 1830, 1837, 1844, 1851, 1858, 1865, 1872, 1879,
#        1886, 1893, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908,
#        1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919,
#        1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930,
#        1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941,
#        1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952,
#        1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963,
#        1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974,
#        1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985,
#        1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996,
#        1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020])

# %%
for temp_year in tqdm(years):
    graph.figure(figsize=(16,9))
    df_temp = df.loc[df['year'] <= temp_year]

    ax = graph.axes(projection=ccrs.PlateCarree())
    ax.coastlines()
    ax.gridlines(draw_labels=True)
    ax.set_extent([-180, -30, 10, 90], crs=ccrs.PlateCarree())

    sns.scatterplot(df_temp['longitude'], df_temp['latitude'], transform=ccrs.PlateCarree(), 
                    hue=df_temp['year'], palette='viridis', s=8)
    graph.legend()
    graph.text(-175, 81, f'{temp_year}', fontsize=25)
    
    ax.figure.savefig(f'/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Master_compilation/Z_graphs/GIFS/{temp_year}_fish_data_location.png', 
               dpi=60)
    graph.clf()
# Out:
#   0%|          | 0/156 [00:00<?, ?it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   1%|          | 1/156 [00:00<00:36,  4.28it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   1%|▏         | 2/156 [00:00<00:44,  3.48it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   2%|▏         | 3/156 [00:00<00:41,  3.65it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   3%|▎         | 4/156 [00:01<00:42,  3.58it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   3%|▎         | 5/156 [00:01<00:41,  3.65it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   4%|▍         | 6/156 [00:01<00:38,  3.89it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   4%|▍         | 7/156 [00:01<00:36,  4.05it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   5%|▌         | 8/156 [00:02<00:37,  3.97it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   6%|▌         | 9/156 [00:02<00:36,  4.00it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   6%|▋         | 10/156 [00:02<00:36,  3.95it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   7%|▋         | 11/156 [00:02<00:36,  3.93it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   8%|▊         | 12/156 [00:03<00:35,  4.06it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   8%|▊         | 13/156 [00:03<00:33,  4.24it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#   9%|▉         | 14/156 [00:03<00:35,  4.05it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  10%|▉         | 15/156 [00:03<00:32,  4.29it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  10%|█         | 16/156 [00:04<00:32,  4.29it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  11%|█         | 17/156 [00:04<00:31,  4.37it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  12%|█▏        | 18/156 [00:04<00:30,  4.47it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  12%|█▏        | 19/156 [00:04<00:30,  4.54it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  13%|█▎        | 20/156 [00:04<00:30,  4.51it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  13%|█▎        | 21/156 [00:05<00:30,  4.45it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  14%|█▍        | 22/156 [00:05<00:30,  4.44it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  15%|█▍        | 23/156 [00:05<00:30,  4.34it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  15%|█▌        | 24/156 [00:05<00:30,  4.35it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  16%|█▌        | 25/156 [00:06<00:29,  4.40it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  17%|█▋        | 26/156 [00:06<00:33,  3.93it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  17%|█▋        | 27/156 [00:06<00:33,  3.89it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  18%|█▊        | 28/156 [00:06<00:34,  3.68it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  19%|█▊        | 29/156 [00:07<00:35,  3.54it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  19%|█▉        | 30/156 [00:07<00:37,  3.32it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  20%|█▉        | 31/156 [00:07<00:38,  3.21it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  21%|██        | 32/156 [00:08<00:37,  3.30it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  21%|██        | 33/156 [00:08<00:44,  2.77it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  22%|██▏       | 34/156 [00:09<00:43,  2.83it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  22%|██▏       | 35/156 [00:09<00:42,  2.82it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  23%|██▎       | 36/156 [00:09<00:43,  2.78it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  24%|██▎       | 37/156 [00:10<00:46,  2.56it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  24%|██▍       | 38/156 [00:10<00:46,  2.52it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  25%|██▌       | 39/156 [00:11<00:48,  2.40it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  26%|██▌       | 40/156 [00:11<00:53,  2.17it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  26%|██▋       | 41/156 [00:12<00:56,  2.03it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  27%|██▋       | 42/156 [00:12<01:02,  1.83it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  28%|██▊       | 43/156 [00:13<01:04,  1.76it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  28%|██▊       | 44/156 [00:14<01:03,  1.77it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  29%|██▉       | 45/156 [00:14<01:01,  1.81it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  29%|██▉       | 46/156 [00:15<01:01,  1.80it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  30%|███       | 47/156 [00:15<01:01,  1.77it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  31%|███       | 48/156 [00:16<01:01,  1.76it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  31%|███▏      | 49/156 [00:17<01:06,  1.61it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  32%|███▏      | 50/156 [00:17<01:04,  1.63it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  33%|███▎      | 51/156 [00:18<01:04,  1.62it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  33%|███▎      | 52/156 [00:18<01:03,  1.63it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  34%|███▍      | 53/156 [00:19<01:02,  1.64it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  35%|███▍      | 54/156 [00:20<01:03,  1.61it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  35%|███▌      | 55/156 [00:20<01:03,  1.59it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  36%|███▌      | 56/156 [00:21<01:04,  1.56it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  37%|███▋      | 57/156 [00:22<01:01,  1.60it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  37%|███▋      | 58/156 [00:22<01:00,  1.62it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  38%|███▊      | 59/156 [00:23<01:00,  1.60it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  38%|███▊      | 60/156 [00:24<01:01,  1.55it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  39%|███▉      | 61/156 [00:24<01:00,  1.56it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  40%|███▉      | 62/156 [00:25<01:01,  1.53it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  40%|████      | 63/156 [00:26<01:03,  1.47it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  41%|████      | 64/156 [00:26<01:04,  1.43it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  42%|████▏     | 65/156 [00:27<01:05,  1.39it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  42%|████▏     | 66/156 [00:28<01:08,  1.32it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  43%|████▎     | 67/156 [00:29<01:09,  1.27it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  44%|████▎     | 68/156 [00:30<01:12,  1.22it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  44%|████▍     | 69/156 [00:31<01:14,  1.17it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  45%|████▍     | 70/156 [00:32<01:17,  1.10it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  46%|████▌     | 71/156 [00:33<01:19,  1.07it/s]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  46%|████▌     | 72/156 [00:34<01:25,  1.02s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  47%|████▋     | 73/156 [00:35<01:29,  1.07s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  47%|████▋     | 74/156 [00:36<01:31,  1.12s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  89%|████████▉ | 139/156 [10:41<07:45, 27.40s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  90%|████████▉ | 140/156 [11:10<07:29, 28.08s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  90%|█████████ | 141/156 [11:40<07:07, 28.49s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  91%|█████████ | 142/156 [12:11<06:52, 29.43s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  92%|█████████▏| 143/156 [12:42<06:26, 29.75s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  92%|█████████▏| 144/156 [13:13<06:00, 30.01s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  93%|█████████▎| 145/156 [13:45<05:37, 30.69s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  94%|█████████▎| 146/156 [14:23<05:30, 33.03s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  94%|█████████▍| 147/156 [15:04<05:17, 35.27s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  95%|█████████▍| 148/156 [15:45<04:55, 36.95s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  96%|█████████▌| 149/156 [16:19<04:13, 36.21s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  96%|█████████▌| 150/156 [16:58<03:42, 37.12s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  97%|█████████▋| 151/156 [17:39<03:10, 38.04s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  97%|█████████▋| 152/156 [18:15<02:29, 37.44s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  98%|█████████▊| 153/156 [18:52<01:52, 37.40s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  99%|█████████▊| 154/156 [19:30<01:15, 37.59s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
#  99%|█████████▉| 155/156 [20:14<00:39, 39.41s/it]/home/arshad/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /home/arshad/miniconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/arshad/miniconda3/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   inframe=inframe)
# 100%|██████████| 156/156 [20:54<00:00,  8.04s/it]

# %%
image_folder = '/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Master_compilation/Z_graphs/GIFS/'

images = [x for x in os.listdir(image_folder) if x.endswith('.png')]
sorted_images = sorted(images, key=lambda x: int(x.split('_')[0]))
gif=[]

for file in tqdm(sorted_images, total=len(sorted_images)):
    gif.append(imageio.imread(f'{image_folder}{file}'))
# Out:
# 100%|██████████| 167/167 [00:03<00:00, 45.82it/s]

# %%
imageio.mimsave('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Master_compilation/Z_graphs/fish_data_location_year.gif', 
                gif)

# %%
df['year'].min()
# Out:
# 1655.0

# %% [markdown]
# # Ontario

# %%
df = pd.read_csv('/mnt/c/Users/imrit/Desktop/fish_community_ontario_1957_2017_v3_feb_9.csv')
df.head()
# Out:
#   waterbody_name site_description  year        lat_long   latitude  longitude  \
# 0       Frere L.            2JE16  1957   47.517_-79.85  47.516667 -79.850000
# 1    Sunshine L.            2JD06  1957   47.565_-80.62  47.564722 -80.620000
# 2       Gerry L.            2JD08  1958   47.95_-80.783  47.950000 -80.783333
# 3     Gourlay L.            4MB01  1958  48.317_-79.883  48.316667 -79.883333
# 4     Old Man L.            4MB01  1958    48.3_-79.867  48.300000 -79.866667
#
#    tds_mg_l  air_temperature  acipenser_fulvescens  alosa_pseudoharengus  ...  \
# 0       0.0             25.6                   NaN                   NaN  ...
# 1      98.0             17.8                   NaN                   NaN  ...
# 2       0.0             15.6                   NaN                   NaN  ...
# 3       0.0             17.8                   NaN                   NaN  ...
# 4       0.0             20.0                   NaN                   NaN  ...
#
#    semotius_spp  squalius_cephalus  stizostedion_spp  umbra_limi  \
# 0           NaN                NaN               NaN         NaN
# 1           NaN                NaN               NaN         NaN
# 2           NaN                NaN               NaN         NaN
# 3           NaN                NaN               NaN         NaN
# 4           NaN                NaN               NaN         NaN
#
#    conductivity  surface_area  growing_degree  depth_max  depth_mean  \
# 0           0.0          18.8            1537       13.4         0.0
# 1           0.0          32.7            1491       12.8         4.3
# 2           0.0           6.8            1464        2.4         1.9
# 3           0.0          25.3            1449       21.3         9.4
# 4           0.0          16.0            1463        6.7         3.2
#
#    secchi_depth
# 0           0.0
# 1           4.4
# 2           2.4
# 3           4.6
# 4           4.6
#
# [5 rows x 167 columns]

# %%
df['study_period'] = np.where(df['year'] < 2000, 0, 1)
df['study_period'] = np.where((df['year'] < 2000) & (df['year'] > 1900), 5, df['study_period'])

# %%
df['study_period'].unique()
# Out:
# array([5, 1])

# %%
graph.figure(figsize=(16,9))
df['year'].value_counts().plot(kind='bar')
graph.show()

# %% [markdown]
# # Nick Watersheds

# %%
canada_lakes = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/hydrolakes_ahi_bsm_sapna_lake_caracteristics_aug_26.csv')
print(len(canada_lakes))

canada_lakes.drop_duplicates(inplace = True)

print(len(canada_lakes))
display(canada_lakes.head())
# Out:
# 24209
# 24209
#    Hylak_id   wby_name Country Continent  lake_area_km2  mean_depth_m  \
# 0       NaN  Bowlby P.     NaN       NaN          0.001           1.5
# 1       NaN      B, L.     NaN       NaN          0.001           NaN
# 2       NaN    H-A, L.     NaN       NaN          0.001           NaN
# 3       NaN    Eby Ph.     NaN       NaN          0.002           1.2
# 4       NaN  Vances L.     NaN       NaN          0.002           1.6
#
#    lake_elevation_(m)  longitude   latitude  dataset  surface_area_ha  \
# 0               201.0 -80.261111  42.793056  ahi_bsm              NaN
# 1               326.0 -80.200000  43.450000  ahi_bsm              NaN
# 2               332.0 -80.166667  43.500000  ahi_bsm              NaN
# 3               320.0 -80.163333  48.032500  ahi_bsm              NaN
# 4               265.0 -81.375000  44.233889  ahi_bsm              NaN
#
#    max_depth_m made_up_code
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %%
# ildf
gpd_canada_lakes = gpd.GeoDataFrame(canada_lakes, 
                                    geometry=gpd.points_from_xy(canada_lakes['longitude'], canada_lakes['latitude']))
gpd_canada_lakes.head()
# Out:
#    Hylak_id   wby_name Country Continent  lake_area_km2  mean_depth_m  \
# 0       NaN  Bowlby P.     NaN       NaN          0.001           1.5
# 1       NaN      B, L.     NaN       NaN          0.001           NaN
# 2       NaN    H-A, L.     NaN       NaN          0.001           NaN
# 3       NaN    Eby Ph.     NaN       NaN          0.002           1.2
# 4       NaN  Vances L.     NaN       NaN          0.002           1.6
#
#    lake_elevation_(m)  longitude   latitude  dataset  surface_area_ha  \
# 0               201.0 -80.261111  42.793056  ahi_bsm              NaN
# 1               326.0 -80.200000  43.450000  ahi_bsm              NaN
# 2               332.0 -80.166667  43.500000  ahi_bsm              NaN
# 3               320.0 -80.163333  48.032500  ahi_bsm              NaN
# 4               265.0 -81.375000  44.233889  ahi_bsm              NaN
#
#    max_depth_m made_up_code                    geometry
# 0          NaN          NaN  POINT (-80.26111 42.79306)
# 1          NaN          NaN  POINT (-80.20000 43.45000)
# 2          NaN          NaN  POINT (-80.16667 43.50000)
# 3          NaN          NaN  POINT (-80.16333 48.03250)
# 4          NaN          NaN  POINT (-81.37500 44.23389)

# %%
nick_shapefile = gpd.read_file('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Nick_Mandrak/Canada_shapefiles/Canada_watersheds_hydrolakes_our_lake_counts_proper_shapefile.shp')
nick_shapefile.head()
# Out:
#   WSCSSDA    TWS_Area_m  out_lakes_  hydro_lake  \
# 0    08JD  6.266462e+09        27.0       116.0
# 1    05AK  5.335010e+09         2.0        31.0
# 2    06CE  4.591652e+09         5.0       872.0
# 3    07HE  6.463431e+09         3.0       121.0
# 4    06CD  1.911540e+10        60.0      3054.0
#
#                                             geometry
# 0  POLYGON ((-125.41910 55.11623, -125.41885 55.1...
# 1  POLYGON ((-109.89815 50.92035, -109.89509 50.9...
# 2  POLYGON ((-105.14596 56.98348, -105.14677 56.9...
# 3  POLYGON ((-116.42664 57.94598, -116.42025 57.9...
# 4  POLYGON ((-104.27707 56.09364, -104.27596 56.0...

# %%
list_of_points = gpd.points_from_xy(canada_lakes.longitude, canada_lakes.latitude)

df_points = gpd.GeoSeries(list_of_points)
print(len(df_points))
# Out:
# 24209

# %%
for i, row in tqdm(nick_shapefile.iterrows()):
    poly = row.geometry
    if isinstance(poly,MultiPolygon):
        count = 0
        for p in list(poly):
            count = count + df_points.intersects(p).sum()
    else:
        count = df_points.intersects(poly).sum()
    nick_shapefile.loc[i,'our_lakes_count'] = count
# Out:
# 991it [11:22,  1.45it/s]

# %%
watershed_counts = pd.Series(nick_shapefile['out_lakes_'].values)
watershed_counts.replace(0, 0.1, inplace=True)
labels = ['0', '1-5', '6-10', '11-30', '30-50', '50-100', '>100']

cut_watershed_counts = pd.cut(watershed_counts, bins=[0, 1, 5, 10, 30, 50, 100, 900], labels=labels)
nick_shapefile['binned_our_counts'] = cut_watershed_counts

nick_shapefile.head(10)
# Out:
#   WSCSSDA    TWS_Area_m  out_lakes_  hydro_lake  \
# 0    08JD  6.266462e+09        27.0       116.0
# 1    05AK  5.335010e+09         2.0        31.0
# 2    06CE  4.591652e+09         5.0       872.0
# 3    07HE  6.463431e+09         3.0       121.0
# 4    06CD  1.911540e+10        60.0      3054.0
# 5    08JC  8.817841e+09        71.0       248.0
# 6    07HD  1.534211e+09         0.1        19.0
# 7    05AH  6.343748e+09        10.0        55.0
# 8    07HF  3.472724e+09         3.0        34.0
# 9    05AG  3.325150e+09         6.0        17.0
#
#                                             geometry  our_lakes_count  \
# 0  POLYGON ((-125.41910 55.11623, -125.41885 55.1...             27.0
# 1  POLYGON ((-109.89815 50.92035, -109.89509 50.9...              2.0
# 2  POLYGON ((-105.14596 56.98348, -105.14677 56.9...              5.0
# 3  POLYGON ((-116.42664 57.94598, -116.42025 57.9...              3.0
# 4  POLYGON ((-104.27707 56.09364, -104.27596 56.0...             60.0
# 5  POLYGON ((-123.05382 54.02521, -123.05300 54.0...             71.0
# 6  POLYGON ((-117.01620 57.83971, -117.01000 57.8...              0.0
# 7  POLYGON ((-109.83156 49.91647, -109.83073 49.9...             10.0
# 8  POLYGON ((-116.04024 58.35171, -116.04050 58.3...              3.0
# 9  POLYGON ((-111.70162 49.93916, -111.70446 49.9...              6.0
#
#   binned_hydro_counts binned_our_counts
# 0             101-500             11-30
# 1               1-100               1-5
# 2            501-1000               1-5
# 3             101-500               1-5
# 4           1001-5000            50-100
# 5             101-500            50-100
# 6               1-100                 0
# 7               1-100              6-10
# 8               1-100               1-5
# 9               1-100              6-10

# %%
fig, ax = graph.subplots(figsize=(16, 9))

nick_shapefile.plot(column='binned_our_counts', legend=True, cmap='OrRd', figsize=(16, 9), zorder=1, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=2, markersize=0.0001)
graph.xlabel('Longitude', fontsize=13, labelpad=3)
graph.ylabel('Latitude', fontsize=13)
# fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/canadian_lakes_watershed_density.png', bbox_inches='tight')
graph.show()

# %%
fig, ax = graph.subplots(figsize=(12, 9))

nick_shapefile.boundary.plot(figsize=(12, 9), zorder=2, edgecolor='black', linewidth = 0.05, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=1, markersize=2)
graph.xlabel('Longitude', fontsize=15, labelpad=3)
graph.ylabel('Latitude', fontsize=15)
# fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/canadian_lakes_watershed_borders_markers.png', 
#             bbox_inches='tight')
graph.show()

# %%
watershed_counts = pd.Series(nick_shapefile['hydro_lake'].values)
watershed_counts.replace(0, 0.1, inplace=True)
labels = ['0', '1-100', '101-500', '501-1000', '1001-5000', '5001-10000', '>10000']

cut_watershed_counts = pd.cut(watershed_counts, bins=[0, 1, 100, 500, 1000, 5000, 10000, 2000000], labels=labels)
nick_shapefile['binned_hydro_counts'] = cut_watershed_counts

nick_shapefile.head(10)
# Out:
#   WSCSSDA    TWS_Area_m  out_lakes_  hydro_lake  \
# 0    08JD  6.266462e+09        27.0       116.0
# 1    05AK  5.335010e+09         2.0        31.0
# 2    06CE  4.591652e+09         5.0       872.0
# 3    07HE  6.463431e+09         3.0       121.0
# 4    06CD  1.911540e+10        60.0      3054.0
# 5    08JC  8.817841e+09        71.0       248.0
# 6    07HD  1.534211e+09         0.1        19.0
# 7    05AH  6.343748e+09        10.0        55.0
# 8    07HF  3.472724e+09         3.0        34.0
# 9    05AG  3.325150e+09         6.0        17.0
#
#                                             geometry  our_lakes_count  \
# 0  POLYGON ((-125.41910 55.11623, -125.41885 55.1...             27.0
# 1  POLYGON ((-109.89815 50.92035, -109.89509 50.9...              2.0
# 2  POLYGON ((-105.14596 56.98348, -105.14677 56.9...              5.0
# 3  POLYGON ((-116.42664 57.94598, -116.42025 57.9...              3.0
# 4  POLYGON ((-104.27707 56.09364, -104.27596 56.0...             60.0
# 5  POLYGON ((-123.05382 54.02521, -123.05300 54.0...             71.0
# 6  POLYGON ((-117.01620 57.83971, -117.01000 57.8...              0.0
# 7  POLYGON ((-109.83156 49.91647, -109.83073 49.9...             10.0
# 8  POLYGON ((-116.04024 58.35171, -116.04050 58.3...              3.0
# 9  POLYGON ((-111.70162 49.93916, -111.70446 49.9...              6.0
#
#   binned_hydro_counts binned_our_counts
# 0             101-500             11-30
# 1               1-100               1-5
# 2            501-1000               1-5
# 3             101-500               1-5
# 4           1001-5000            50-100
# 5             101-500            50-100
# 6               1-100                 0
# 7               1-100              6-10
# 8               1-100               1-5
# 9               1-100              6-10

# %%
fig, ax = graph.subplots(figsize=(16, 9))

nick_shapefile.plot(column='binned_hydro_counts', legend=True, cmap='OrRd', zorder=2, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=1, markersize=0.0001)
graph.xlabel('Longitude', fontsize=13, labelpad=3)
graph.ylabel('Latitude', fontsize=13)
# fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/canadian_watershed_fish_locations_density.png', 
#             bbox_inches='tight')
graph.show()

# %%
0, 1-100, 101-1000, 1001-10000, >10000

# %%
fig, ax = graph.subplots(figsize=(16, 9))

nick_shapefile.plot(column='hydro_lake', legend=True, cmap='OrRd', scheme = 'quantiles', zorder=2, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=1, markersize=0.0001)
graph.xlabel('Longitude', fontsize=13, labelpad=3)
graph.ylabel('Latitude', fontsize=13)
# fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/canadian_lakes_watershed_density.png', bbox_inches='tight')
graph.show()

# %%
fig, ax = graph.subplots(figsize=(16, 9))

nick_shapefile.plot(column='binned_hydro_counts', legend=True, cmap='OrRd', zorder=2, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=1, markersize=0.0001)
graph.xlabel('Longitude', fontsize=13, labelpad=3)
graph.ylabel('Latitude', fontsize=13)
# fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/canadian_lakes_watershed_density.png', bbox_inches='tight')
graph.show()

# %%
fig, ax = graph.subplots(figsize=(16, 9))

nick_shapefile.plot(column='binned_hydro_counts', legend=True, cmap='OrRd', zorder=2, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=1, markersize=0.0001)
graph.xlabel('Longitude', fontsize=13, labelpad=3)
graph.ylabel('Latitude', fontsize=13)
fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/canadian_watershed_hydrolakes_density.png', 
            bbox_inches='tight')
graph.show()

# %%
fig, ax = graph.subplots(figsize=(16, 9))

nick_shapefile.plot(column='hydro_lake', legend=True, cmap='OrRd', scheme = 'quantiles', zorder=1, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=2, markersize=1)
graph.xlabel('Longitude', fontsize=13, labelpad=3)
graph.ylabel('Latitude', fontsize=13)
# fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/canadian_lakes_watershed_density.png', bbox_inches='tight')
graph.show()

# %%
fig, ax = graph.subplots(figsize=(16, 9))

nick_shapefile.plot(column='hydro_lake', legend=True, cmap='Blues', scheme = 'quantiles', zorder=1, ax=ax)
gpd_canada_lakes.plot(ax = ax, zorder=2, markersize=0.0001)
graph.xlabel('Longitude', fontsize=13, labelpad=3)
graph.ylabel('Latitude', fontsize=13)
# fig.savefig('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Graphs/canadian_lakes_watershed_density.png', bbox_inches='tight')
graph.show()
