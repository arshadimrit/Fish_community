# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as graph
import seaborn as sns

import cartopy.crs as ccrs

import statsmodels

import os
from tqdm import tqdm, trange

from convertbng.util import convert_bng, convert_lonlat
import utm

# %%
# code and species dictionary

code_df = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Alberta/To_look_at/Banff_NP_Freshwater_Lake_Fish_Index_2017_data_dictionary.csv')
# code_df = code_df.iloc[:-6]
code_df.rename(columns={'Data_Value_Valeur_de_la_donnée': 'code_name', 
                        'Value_Description_EN_Description_de_la_valeur': 'common_name'}, inplace=True)
code_df = code_df[['code_name', 'common_name']]
code_df['common_name'] = code_df['common_name'].str.lower().str.replace(' ', '_')
display(code_df.sample(5))

dict_code_name = code_df.set_index('code_name').to_dict()['common_name']
# Out:
#    code_name             common_name
# 39      NRDC  northern_redbelly_dace
# 18      ARGR         arctic_grayling
# 24      BURB                  burbot
# 25      CISC                   cisco
# 8       LNSC         longnose_sucker

# %%
new_codes = {'LNDC': 'longnose_dace', 'BNTR': 'brown_trout', 'RNTR1': 'rainbow_trout', 'CTTR1': 'cutthroat_trout', 
             'WHSC': 'white_sucker', 'BLTRCTTR(N&I)': 'bull_trout_x_cutthroat_trout', 'CTTR(hybrids)': 'cutthroat_trout', 
             'CTTRhybrids': 'cutthroat_trout', 'SUCK': 'white_sucker'}

dict_code_name.update(new_codes)

# %%
# Species dictionay

species_name_df = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/species_name_dictionary.csv')

dict_species_name = species_name_df.set_index('common_name').to_dict()['scientific_name']

# %%
species_name_df = pd.DataFrame.from_dict({'common_name': list(dict_species_name.keys()), 
                                        'scientific_name' : list(dict_species_name.values())})
# species_name_df.to_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/species_name_dictionary.csv', index=False)

# %% [markdown]
# # Sapna

# %% [markdown]
# ### 2013 Ontario Lakes

# %%
df = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Ontario/Used/Ontario lakes and fish database_October2013.csv')

df.drop(columns=['Lake Code', 'LATITUDE', 'LONGITUDE', 'Total # of spp', 'Water temp sampling date', 'Source'], inplace=True)

df.columns = df.columns.str.lower().str.rstrip().str.replace(' ', '_').str.replace('_sp', '_spp', regex=True)
df.rename(columns=dict_species_name, inplace=True)

df['lat_long'] = df['latitude'].round(3).astype(str) + '_' + df['longitude'].round(3).astype(str)

cols = ['year', 'lat_long']
cols.extend(list(df.columns[:-2]))

df = df[cols]
df = df.sum(axis=1, level=0)

for col in list(df.columns)[21:]:
    df[col] = df[col].replace(0, np.nan)
    df[col] = np.where(df[col].notnull(), 1, np.nan)
    
display(df.head())
print(len(df['lat_long'].unique()))
# Out:
#      year        lat_long           lake_name  wshed   latitude  longitude  \
# 0  1968.0  50.338_-93.404          Aerobus L.  5QE04  50.337778 -93.404444
# 1  1985.0  50.026_-93.155          Affleck L.  5QD01  50.026389 -93.154722
# 2  1977.0  49.459_-92.469       Aiabewatik L.  5QD01  49.459444 -92.468611
# 3  1975.0  50.029_-92.952  Little Amesdale L.  5QD04  50.028889 -92.952500
# 4  1985.0   50.11_-92.466            Alder L.  5QB01  50.110000 -92.466389
#
#    surface_area_(ha)  maximum_depth_(m)  mean_depth  island_perimeter_(km)  \
# 0             1947.7               43.9        15.4                    4.8
# 1              168.6               15.5         7.3                    0.3
# 2              162.6               33.0         9.0                    5.2
# 3               36.8                4.3         1.8                    0.0
# 4              192.3               14.8         6.2                    0.0
#
#    ...  myoxocephalus_thompsonii  cottus_spp  \
# 0  ...                       NaN         NaN
# 1  ...                       NaN         NaN
# 2  ...                       NaN         NaN
# 3  ...                       NaN         NaN
# 4  ...                       NaN         NaN
#
#    esox_lucius_x_esox_americanus_vermiculatus  chrosomus_sppp  \
# 0                                         NaN             NaN
# 1                                         NaN             NaN
# 2                                         NaN             NaN
# 3                                         NaN             NaN
# 4                                         NaN             NaN
#
#    chrosomus_eos_x_chrosomus_neogaeus  chrosomus_eos_x_margariscus_nachtriebi  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#    chrosomus_neogaeus_x_margariscus_nachtriebi  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    luxilus_cornutus_x_semotilus_atromaculatus  lepomis_sppp  \
# 0                                         NaN           NaN
# 1                                         NaN           NaN
# 2                                         NaN           NaN
# 3                                         NaN           NaN
# 4                                         NaN           NaN
#
#    lepomis_gibbosus_x_lepomis_macrochirus
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 154 columns]
# 9758

# %%
print(df['year'].min(), df['year'].max())
# Out:
# 1957.0 1986.0

# %%
df.to_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Ontario/Processed/sapna_ontario_lakes_occurence_1957_1986.csv', 
          index=False)

# %% [markdown]
# ### York Request ONBSM
# ##### can get abundance

# %%
df_location = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Ontario/York_request_ONBSM_Location.csv')
df_location.drop(columns=['Target_species', 'Lake_selection'], inplace=True)
df_location['year'] = pd.DatetimeIndex(pd.to_datetime(df_location['Survey_year_month'])).year
df_location['lat_long'] = df_location['Lat'].round(3).astype(str) + '_' + df_location['Long'].round(3).astype(str)
print(f'Location size: {len(df_location)}')

df_variables = df_location[['year', 'lat_long', 'Area_ha', 'Depth_Max', 'Depth_Mn', 'SDF', 'pLittoral', 'Secchi_Su', 
                            'Thermo_Obs', 'Thermo_Pred', 'TotalPhosphorus(ugL)', 'TrueColour_pctl', 'pH_pctl', 
                            'Conductivity(uScms)', 'TDS (mg/L)', 'DD5_8110', 'AirTemp_8110']]

df_variables = df_variables.groupby(['year', 'lat_long']).mean().reset_index()
print(f'Variables size: {len(df_variables)}')
display(df_variables.head())
# Out:
# Location size: 1409
# Variables size: 1406
#      year        lat_long  Area_ha  Depth_Max  Depth_Mn       SDF  pLittoral  \
# 0  2007.0  44.584_-78.844   4764.0       12.8       5.0  2.984901   0.467848
# 1  2007.0  48.579_-90.419   3407.0       54.9      18.1  3.101563   0.115151
# 2  2007.0  49.111_-91.881   8467.0       56.4      22.1  5.469126   0.140908
# 3  2008.0  43.057_-81.176    233.0       12.2       3.6  2.478946   0.674001
# 4  2008.0  44.172_-78.855   6650.0        6.1       1.3  5.075877   0.992000
#
#    Secchi_Su  Thermo_Obs  Thermo_Pred  TotalPhosphorus(ugL)  TrueColour_pctl  \
# 0        NaN         NaN     9.770048                   NaN              NaN
# 1        NaN         NaN    13.763188                   8.2             12.0
# 2        NaN        11.0    15.693298                   5.2             50.0
# 3        1.2         NaN     6.269517                  52.5             64.0
# 4        0.5         NaN          NaN                  10.1             33.0
#
#    pH_pctl  Conductivity(uScms)  TDS (mg/L)  DD5_8110  AirTemp_8110
# 0      NaN                  NaN         NaN    1975.0           6.4
# 1     38.0                 66.0     43.9560    1453.0           2.4
# 2     40.0                 25.3     16.8498    1615.0           2.8
# 3     64.0                549.0    365.6340    2246.0           8.1
# 4    100.0                390.0    259.7400    2065.0           7.2

# %%
df_location = df_location[['year', 'lat_long', 'Lat', 'Long', 
                           'BsM_Cycle', 'FMZ', 'Wby_LID', 'Wby_Name']].merge(df_variables, on=['year', 'lat_long'])
display(df_location.head())
print(len(df_location))
# Out:
#      year        lat_long       Lat      Long  BsM_Cycle  FMZ        Wby_LID  \
# 0  2012.0   54.146_-85.04  54.14639 -85.03972        1.0  1.0  16-6284-60018
# 1  2012.0  54.165_-85.689  54.16500 -85.68917        1.0  1.0  16-5856-60025
# 2  2012.0  54.334_-85.014  54.33444 -85.01361        1.0  1.0  16-6292-60223
# 3  2011.0  52.579_-91.541  52.57861 -91.54139        1.0  2.0  15-5988-58262
# 4  2011.0   52.91_-87.384  52.90972 -87.38417        1.0  2.0  16-4753-58628
#
#         Wby_Name  Area_ha  Depth_Max  ...  Secchi_Su  Thermo_Obs  Thermo_Pred  \
# 0        Pine L.    299.0      12.66  ...        1.9        11.0     8.846716
# 1  Shamattawa L.    963.0       7.20  ...        1.2         NaN          NaN
# 2      Spruce L.   1082.0      16.00  ...        2.0         NaN    10.110772
# 3     Windigo L.   8028.0       7.00  ...        1.6         NaN          NaN
# 4      Winisk L.  25815.0      16.50  ...        3.0         NaN    12.043536
#
#    TotalPhosphorus(ugL)  TrueColour_pctl  pH_pctl  Conductivity(uScms)  \
# 0                  12.8            100.0    100.0                137.0
# 1                  11.5            100.0     50.0                115.0
# 2                   9.5             50.0    100.0                133.0
# 3                  11.3             63.0     63.0                108.0
# 4                   9.0             50.0     88.0                149.0
#
#    TDS (mg/L)  DD5_8110  AirTemp_8110
# 0      91.242    1069.0          -1.8
# 1      76.590    1073.0          -1.8
# 2      88.578    1059.0          -1.9
# 3      71.928    1329.0          -0.3
# 4      99.234    1179.0          -1.2
#
# [5 rows x 23 columns]
# 1407

# %%
df_species = pd.read_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Ontario/York_request_ONBSM_occurence.csv')
print(len(df_species))

df = df_species.merge(df_location, on=(['BsM_Cycle', 'FMZ', 'Wby_LID']), how='left')
print(len(df))
df.dropna(subset=['SpecName', 'Lat', 'Long'], inplace=True)

df.drop(columns=['BsM_Cycle', 'FMZ', 'Wby_LID', 'SpecCode'], inplace=True)
df['SpecName'] = df['SpecName'].str.lower().str.rstrip().str.replace(' ', '_')
df.replace(dict_species_name, inplace=True)
df.replace({'_sp.': '_spp'}, regex=True, inplace=True)

display(df.sample(5))
# Out:
# 22924
# 22931
#                  Wby_name            SpecName    year        lat_long  \
# 10052  Little Venetian L.    luxilus_cornutus  2011.0  46.941_-81.209
# 5458       White Otter L.    perca_flavescens  2007.0  49.111_-91.881
# 4834             Rugby L.    perca_flavescens  2010.0  49.958_-92.963
# 8677             Raven L.  ameiurus_nebulosus  2015.0   48.052_-79.55
# 14785             Rice L.  ameiurus_nebulosus  2015.0  44.173_-78.186
#
#             Lat      Long            Wby_Name  Area_ha  Depth_Max  Depth_Mn  \
# 10052  46.94055 -81.20916  Little Venetian L.     72.0      22.12       7.3
# 5458   49.11111 -91.88139      White Otter L.   8467.0      56.40      22.1
# 4834   49.95778 -92.96333            Rugby L.   1021.0       7.60       3.4
# 8677   48.05196 -79.55023            Raven L.    581.0      46.90      19.0
# 14785  44.17348 -78.18609             Rice L.   9185.0      13.40       2.6
#
#        ...  Secchi_Su  Thermo_Obs  Thermo_Pred  TotalPhosphorus(ugL)  \
# 10052  ...        6.1         6.0     7.161583                   4.0
# 5458   ...        NaN        11.0    15.693298                   5.2
# 4834   ...        0.8         NaN          NaN                   4.0
# 8677   ...        2.5         8.0    11.407494                  10.0
# 14785  ...        2.2         NaN     8.963688                  11.4
#
#        TrueColour_pctl  pH_pctl  Conductivity(uScms)  TDS (mg/L)  DD5_8110  \
# 10052             32.0    100.0                 21.6     14.3856    1693.0
# 5458              50.0     40.0                 25.3     16.8498    1615.0
# 4834              49.0     69.0                 37.6     25.0416    1662.0
# 8677              32.0      5.0                 41.1     27.3726    1571.0
# 14785             33.0    100.0                232.0    154.5120    2023.0
#
#        AirTemp_8110
# 10052           3.9
# 5458            2.8
# 4834            2.6
# 8677            2.6
# 14785           7.1
#
# [5 rows x 22 columns]

# %%
df = df[~df['SpecName'].isin(['unknown_(any_or_all_fish_sppcies)', 'unidentifiable', 'mixed_scrap_fish_(animal_food)'])]

# %%
# %%time
for col in tqdm(df['SpecName'].unique()):
    df[col] = np.where(df.isin([col]).any(1), 1, np.nan)
    df[col] = df[col].fillna(df.groupby(['year', 'lat_long'])[col].transform('mean'))

display(df.sample(5))  
print(df['year'].min(), df['year'].max())
# Out:
# 100%|██████████| 113/113 [00:16<00:00,  6.84it/s]
#                       Wby_name                SpecName    year  \
# 2131               Thaddeus L.        coregonus_artedi  2009.0
# 9354                Chiblow L.             esox_lucius  2008.0
# 12367  Lac Dollard-des-Ormeaux      carpiodes_cyprinus  2017.0
# 11828           Nosbonsing, L.             esox_lucius  2014.0
# 1194                  Joyce L.  catostomus_commersonii  2013.0
#
#              lat_long       Lat      Long                 Wby_Name  Area_ha  \
# 2131   50.171_-92.881  50.17139 -92.88111              Thaddeus L.   1566.0
# 9354   46.344_-83.049  46.34361 -83.04917               Chiblow L.   1996.0
# 12367  45.594_-74.488  45.59411 -74.48757  Lac Dollard-des-Ormeaux  14414.0
# 11828  46.207_-79.213  46.20715 -79.21294           Nosbonsing, L.   1765.0
# 1194   51.132_-93.014  51.13210 -93.01422                 Joyce L.   1458.0
#
#        Depth_Max  Depth_Mn  ...  lepomis_spp  labidesthes_sicculus  \
# 2131        16.2       8.5  ...          NaN                   NaN
# 9354        66.9      24.1  ...          NaN                   NaN
# 12367       34.0       6.1  ...          NaN                   NaN
# 11828       14.0       5.0  ...          NaN                   NaN
# 1194         6.2       3.1  ...          NaN                   NaN
#
#        esox_americanus  oncorhynchus_tshawytscha  \
# 2131               NaN                       NaN
# 9354               NaN                       NaN
# 12367              NaN                       NaN
# 11828              NaN                       NaN
# 1194               NaN                       NaN
#
#        lepomis_gibbosus_x_lepomis_macrochirus  percopsidae_spp  \
# 2131                                      NaN              NaN
# 9354                                      NaN              NaN
# 12367                                     NaN              NaN
# 11828                                     NaN              NaN
# 1194                                      NaN              NaN
#
#        esox_lucius_x_esox_masquinongy  dorosoma_cepedianum  \
# 2131                              NaN                  NaN
# 9354                              NaN                  NaN
# 12367                             NaN                  NaN
# 11828                             NaN                  NaN
# 1194                              NaN                  NaN
#
#        notropis_stramineus  etheostoma_olmstedi
# 2131                   NaN                  NaN
# 9354                   NaN                  NaN
# 12367                  NaN                  NaN
# 11828                  NaN                  NaN
# 1194                   NaN                  NaN
#
# [5 rows x 135 columns]
# 2007.0 2017.0
# CPU times: user 13.1 s, sys: 3.56 s, total: 16.6 s
# Wall time: 16.6 s

# %%
print(len(df))
df.drop(columns=['SpecName'], inplace=True)
df.drop_duplicates(inplace=True)
print(len(df))

display(df.sample(5))
df.to_csv('/mnt/c/Users/imrit/Downloads/Sharma_fish_project/Ontario/Processed/York_request_occurence_2007_2017.csv', 
          index=False)
# Out:
# 15951
# 1405
#                  Wby_name    year        lat_long       Lat      Long  \
# 6121             Jolly L.  2013.0  49.168_-89.459  49.16785 -89.45932
# 4366                   NL  2010.0  49.319_-92.059  49.31917 -92.05944
# 13964         Fanshawe L.  2008.0  43.057_-81.176  43.05722 -81.17556
# 7619   South Greenhill L.  2016.0  48.455_-83.887  48.45508 -83.88685
# 8362     Little Ridley L.  2015.0  47.904_-82.694  47.90407 -82.69446
#
#                  Wby_Name  Area_ha  Depth_Max  Depth_Mn       SDF  ...  \
# 6121             Jolly L.    101.0        5.0       2.1  1.713240  ...
# 4366                   NL    114.0        5.2       2.3  1.394525  ...
# 13964         Fanshawe L.    233.0       12.2       3.6  2.478946  ...
# 7619   South Greenhill L.    110.0        7.0       3.2  2.503808  ...
# 8362     Little Ridley L.     59.0        7.8       2.1  3.176761  ...
#
#        lepomis_spp  labidesthes_sicculus  esox_americanus  \
# 6121           NaN                   NaN              NaN
# 4366           NaN                   NaN              NaN
# 13964          NaN                   NaN              NaN
# 7619           NaN                   NaN              NaN
# 8362           NaN                   NaN              NaN
#
#        oncorhynchus_tshawytscha  lepomis_gibbosus_x_lepomis_macrochirus  \
# 6121                        NaN                                     NaN
# 4366                        NaN                                     NaN
# 13964                       NaN                                     NaN
# 7619                        NaN                                     NaN
# 8362                        NaN                                     NaN
#
#        percopsidae_spp  esox_lucius_x_esox_masquinongy  dorosoma_cepedianum  \
# 6121               NaN                             NaN                  NaN
# 4366               NaN                             NaN                  NaN
# 13964              NaN                             NaN                  NaN
# 7619               NaN                             NaN                  NaN
# 8362               NaN                             NaN                  NaN
#
#        notropis_stramineus  etheostoma_olmstedi
# 6121                   NaN                  NaN
# 4366                   NaN                  NaN
# 13964                  NaN                  NaN
# 7619                   NaN                  NaN
# 8362                   NaN                  NaN
#
# [5 rows x 134 columns]

# %% [markdown]
# ### That's it folks!
